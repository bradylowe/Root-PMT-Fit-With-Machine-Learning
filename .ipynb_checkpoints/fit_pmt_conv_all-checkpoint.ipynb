# %% [markdown]
# # Convolutional neural network for classifying Root data fits.
#
#
# Here, we define, train, and save new convolutional models as well as some
# simple model evaluation. We define hyper-parameters, number of layers, and
# training and testing datasets.
#
# Here, at the final layer, the network takes into account chi squared per degree of freedom.

# %% [markdown]
# #### Load necessary packages

# %%
# Load some packages

# Keras packages for network
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, Conv2D, Flatten
from keras.models import Model
from keras.optimizers import Adam, SGD
# For saving model
from keras.models import model_from_json
from keras.layers import concatenate, Lambda

# Some items for plotting and drawing
from keras.utils import plot_model
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG
from PIL import Image
from scipy import misc
import matplotlib.pyplot as plt

# Need numpy
import numpy as np
import nn_utils as utils

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Load root fit data from file

# %%
# Define image file path
im_path="/media/brady/4be7777f-c84c-40ca-af3a-b8c6e4f2f90d/brady/Projects/fit_pmt/images/png_fit_nn/"

# Load dataset
x, y, params = utils.load_dataset_all(im_dir="train", log=False, im_path=im_path)
x_dev, y_dev, params_dev = utils.load_dataset_all(im_dir="dev", log=False, im_path=im_path)

# Grab dimensions of picture
(m, h, w, c) = x.shape
m_dev = x_dev.shape[0]
input_shape = h, w, c
num_params = params.shape[1]

# Print dimensions
print("(m, height, width, channels): (" + str(m) + ", " + str(h) + ", " + str(w) + ", " + str(c) + ")")
print("m_dev: " + str(m_dev))
print("y: " + str(y.shape))
print("params: " + str(params.shape))
# Out:
# (m, height, width, channels): (1396, 236, 348, 3)
# m_dev: 129
# y: (1396, 1)
# params: (1396, 54)

# %%
# Print an image
index = 420
this_image = x[index]
if y[index] == 1:
    print("label: good")
else:
    print("label: bad")
print("label: " + str(y[index]))
print("params: " + str(params[index]))
plt.imshow(np.uint8(utils.get_printable_image(this_image)))
# Out:
# label: good
# label: [1]
# params: [ 0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  2.000000e+01
#   5.000000e-02  6.144692e+02  2.252700e+00  1.000000e-02  2.560000e+00
#   4.000000e+00  2.252700e+00  5.000000e-01  5.000000e-01  1.000000e-03
#  -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
#  -1.000000e+00  0.000000e+00  0.000000e+00  5.000000e-01 -1.000000e+00
#  -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
#   1.000000e+00  1.000000e+00  6.400000e-03  6.130692e+02  1.706800e+00
#   5.000000e-02  5.411800e+00  1.132900e+00  1.556800e+00  1.765000e-01
#   8.235000e-01  2.000000e-04  1.620000e-02  1.270000e-02  1.000000e-03
#   8.910000e-02  1.870000e-02  1.070000e-02  2.800000e-03  3.000000e-03
#   6.254000e+00  1.768000e-01  7.300000e-03  4.130900e+00]

# %% [markdown]
# ## Define and Train multi-layer ConvNet with 2 fully connected layers plus output layer
#
# For the convolutional layer, we will scan over our images with a certain stride and a certain kernal size.
# Each individual scan represents a single neuron in the next layer. Since each scan connects to kernal size squared
# neurons below it, convolutions reduce the number of degrees of freedom. Hopefully, through learning the right filters,
# we can preserve the important information as we reduce it in size.
#
# Once the image has gone through the convolutional layers (and therefore has been reduced to its features vector), we
# can send the resulting vector into some old-fashioned fully-connected layers, and finally into a logistic regression unit.

# %% [markdown]
# ##### Define hyperparameters

# %%
# Initialize
filters = []
kernels = []
strides = []
pools = []
dropouts = []

# Conv1
filters.append(32)
kernels.append(5)
strides.append(2)
pools.append(2)
dropouts.append(0.4)

# Conv2
filters.append(128)
kernels.append(5)
strides.append(2)
pools.append(2)
dropouts.append(0.3)

# Conv3
filters.append(256)
kernels.append(4)
strides.append(2)
pools.append(2)
dropouts.append(0.2)

# Define dense (fully-connected) layer sizes
fc1 = 20
fc2 = 10

# %% [markdown]
# ##### Define keras layers (model)

# %%
def concat_params(input):
    a = input[0]
    b = input[1]
    return concatenate([a,b], axis=1)

# %%
# Define input layer (RGB image matrix)
X = Input(shape=input_shape, name='Input')

# Define additional input info
Params = Input(shape=(num_params,), name='Params')

# Initialize activation as input
a = X
# Loop through all convolutional layers
for i in range(len(filters)):
    # Perform convolution
    a = Conv2D(filters=filters[i], kernel_size=(kernels[i], kernels[i]), strides=(strides[i], strides[i]), name=('conv' + str(i)))(a)
    # Normalize
    a = BatchNormalization(axis=3, name=('bn' + str(i)))(a)
    # Activate
    a = Activation('relu', name=('a' + str(i)))(a)
    # Max-pool
    a = MaxPooling2D((pools[i], pools[i]), name=('max_pool' + str(i)))(a)
    # Dropout
    a = Dropout(rate=dropouts[i])(a)

# Flatten output of convNet
a = Flatten()(a)
# Define first fully connected layer
a = Dense(units=fc1, activation='relu', name='fc0')(a)
# Use some dropout here for regularization
a = Dropout(rate=0.2)(a)

# Activate parameters
a_params = Activation('tanh', name='param_act')(Params)

# Concatenate parameters to activations
a = Lambda(concat_params, name='concat_params')([a, a_params])

# Define second fully connected layer
a = Dense(units=fc2, activation='relu', name='fc1')(a)
# Define output layer 
a = Dense(units=1, activation='sigmoid', name='sigmoid')(a)

# Make the model
model = Model(inputs=[X, Params], outputs=a)

# %% [markdown]
# ##### Define optimizer, loss, and metrics. Compile model.

# %%
# Define optimizer
#opt = Adam(lr=0.01, beta_1=0.9, beta_2=0.999, decay=0.001)
opt = SGD(lr=1.0, decay=1e-6, momentum=0.9, nesterov=True)
# Define loss
loss = 'mean_squared_error'
# Define metrics to use
metrics=['acc']
# Compile model
model.compile(loss=loss, optimizer='sgd', metrics=metrics)
# Print summary
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              (None, 236, 348, 3)  0
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 116, 172, 32) 2432        Input[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 116, 172, 32) 128         conv0[0][0]
# __________________________________________________________________________________________________
# a0 (Activation)                 (None, 116, 172, 32) 0           bn0[0][0]
# __________________________________________________________________________________________________
# max_pool0 (MaxPooling2D)        (None, 58, 86, 32)   0           a0[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 58, 86, 32)   0           max_pool0[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 27, 41, 128)  102528      dropout_13[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 27, 41, 128)  512         conv1[0][0]
# __________________________________________________________________________________________________
# a1 (Activation)                 (None, 27, 41, 128)  0           bn1[0][0]
# __________________________________________________________________________________________________
# max_pool1 (MaxPooling2D)        (None, 13, 20, 128)  0           a1[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 13, 20, 128)  0           max_pool1[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv2D)                  (None, 5, 9, 256)    524544      dropout_14[0][0]
# __________________________________________________________________________________________________
# bn2 (BatchNormalization)        (None, 5, 9, 256)    1024        conv2[0][0]
# __________________________________________________________________________________________________
# a2 (Activation)                 (None, 5, 9, 256)    0           bn2[0][0]
# __________________________________________________________________________________________________
# max_pool2 (MaxPooling2D)        (None, 2, 4, 256)    0           a2[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 2, 4, 256)    0           max_pool2[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 2048)         0           dropout_15[0][0]
# __________________________________________________________________________________________________
# fc0 (Dense)                     (None, 20)           40980       flatten_4[0][0]
# __________________________________________________________________________________________________
# Params (InputLayer)             (None, 54)           0
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 20)           0           fc0[0][0]
# __________________________________________________________________________________________________
# param_act (Activation)          (None, 54)           0           Params[0][0]
# __________________________________________________________________________________________________
# concat_params (Lambda)          (None, 74)           0           dropout_16[0][0]
#                                                                  param_act[0][0]
# __________________________________________________________________________________________________
# fc1 (Dense)                     (None, 10)           750         concat_params[0][0]
# __________________________________________________________________________________________________
# sigmoid (Dense)                 (None, 1)            11          fc1[0][0]
# ==================================================================================================
# Total params: 672,909
# Trainable params: 672,077
# Non-trainable params: 832
# __________________________________________________________________________________________________

# %% [markdown]
# ##### Fit the model to the data (train)

# %%
# Now, fit the model to the data
history = model.fit([x, params], y, validation_data=([x_dev, params_dev], y_dev), epochs=500, batch_size=128)

# List all data in history
print(history.history.keys())
# Summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Train on 1396 samples, validate on 129 samples
# Epoch 1/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0452 - acc: 0.9477 - val_loss: 0.1172 - val_acc: 0.8372
# Epoch 2/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0497 - acc: 0.9348 - val_loss: 0.1197 - val_acc: 0.8372
# Epoch 3/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0487 - acc: 0.9370 - val_loss: 0.1190 - val_acc: 0.8372
# Epoch 4/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0459 - acc: 0.9434 - val_loss: 0.1272 - val_acc: 0.8372
# Epoch 5/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0434 - acc: 0.9470 - val_loss: 0.1298 - val_acc: 0.8140
# Epoch 6/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0416 - acc: 0.9427 - val_loss: 0.1167 - val_acc: 0.8372
# Epoch 7/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0431 - acc: 0.9470 - val_loss: 0.1159 - val_acc: 0.8372
# Epoch 8/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0476 - acc: 0.9405 - val_loss: 0.1245 - val_acc: 0.8295
# Epoch 9/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0494 - acc: 0.9398 - val_loss: 0.1150 - val_acc: 0.8372
# Epoch 10/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0422 - acc: 0.9520 - val_loss: 0.1195 - val_acc: 0.8372
# Epoch 11/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0426 - acc: 0.9506 - val_loss: 0.1207 - val_acc: 0.8372
# Epoch 12/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0415 - acc: 0.9506 - val_loss: 0.1175 - val_acc: 0.8372
# Epoch 13/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0395 - acc: 0.9542 - val_loss: 0.1180 - val_acc: 0.8372
# Epoch 14/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0453 - acc: 0.9420 - val_loss: 0.1130 - val_acc: 0.8527
# Epoch 15/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0464 - acc: 0.9463 - val_loss: 0.1160 - val_acc: 0.8372
# Epoch 16/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0448 - acc: 0.9427 - val_loss: 0.1210 - val_acc: 0.8372
# Epoch 17/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0427 - acc: 0.9484 - val_loss: 0.1175 - val_acc: 0.8372
# Epoch 18/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0455 - acc: 0.9370 - val_loss: 0.1317 - val_acc: 0.8140
# Epoch 19/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0471 - acc: 0.9456 - val_loss: 0.1123 - val_acc: 0.8527
# Epoch 20/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0511 - acc: 0.9391 - val_loss: 0.1171 - val_acc: 0.8372
# Epoch 21/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0442 - acc: 0.9441 - val_loss: 0.1221 - val_acc: 0.8372
# Epoch 22/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0488 - acc: 0.9327 - val_loss: 0.1363 - val_acc: 0.8062
# Epoch 23/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0471 - acc: 0.9427 - val_loss: 0.1229 - val_acc: 0.8295
# Epoch 24/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0390 - acc: 0.9542 - val_loss: 0.1269 - val_acc: 0.8217
# Epoch 25/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0467 - acc: 0.9405 - val_loss: 0.1357 - val_acc: 0.8062
# Epoch 26/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0421 - acc: 0.9427 - val_loss: 0.1242 - val_acc: 0.8295
# Epoch 27/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0415 - acc: 0.9520 - val_loss: 0.1223 - val_acc: 0.8295
# Epoch 28/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0424 - acc: 0.9463 - val_loss: 0.1215 - val_acc: 0.8295
# Epoch 29/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0436 - acc: 0.9405 - val_loss: 0.1312 - val_acc: 0.8140
# Epoch 30/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0461 - acc: 0.9334 - val_loss: 0.1261 - val_acc: 0.8217
# Epoch 31/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0388 - acc: 0.9549 - val_loss: 0.1234 - val_acc: 0.8295
# Epoch 32/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0415 - acc: 0.9542 - val_loss: 0.1346 - val_acc: 0.8062
# Epoch 33/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0403 - acc: 0.9491 - val_loss: 0.1330 - val_acc: 0.7984
# Epoch 34/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0421 - acc: 0.9484 - val_loss: 0.1220 - val_acc: 0.8372
# Epoch 35/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0439 - acc: 0.9484 - val_loss: 0.1185 - val_acc: 0.8372
# Epoch 36/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0445 - acc: 0.9441 - val_loss: 0.1153 - val_acc: 0.8450
# Epoch 37/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0431 - acc: 0.9484 - val_loss: 0.1171 - val_acc: 0.8372
# Epoch 38/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0388 - acc: 0.9577 - val_loss: 0.1135 - val_acc: 0.8450
# Epoch 39/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0419 - acc: 0.9491 - val_loss: 0.1236 - val_acc: 0.8372
# Epoch 40/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0415 - acc: 0.9549 - val_loss: 0.1181 - val_acc: 0.8372
# Epoch 41/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0427 - acc: 0.9470 - val_loss: 0.1307 - val_acc: 0.8140
# Epoch 42/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0403 - acc: 0.9506 - val_loss: 0.1235 - val_acc: 0.8295
# Epoch 43/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0401 - acc: 0.9477 - val_loss: 0.1225 - val_acc: 0.8372
# Epoch 44/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0392 - acc: 0.9470 - val_loss: 0.1171 - val_acc: 0.8450
# Epoch 45/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0396 - acc: 0.9513 - val_loss: 0.1119 - val_acc: 0.8450
# Epoch 46/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0445 - acc: 0.9398 - val_loss: 0.1137 - val_acc: 0.8527
# Epoch 47/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0411 - acc: 0.9499 - val_loss: 0.1230 - val_acc: 0.8295
# Epoch 48/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0436 - acc: 0.9448 - val_loss: 0.1258 - val_acc: 0.8295
# Epoch 49/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0386 - acc: 0.9520 - val_loss: 0.1245 - val_acc: 0.8217
# Epoch 50/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0453 - acc: 0.9434 - val_loss: 0.1192 - val_acc: 0.8372
# Epoch 51/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0432 - acc: 0.9477 - val_loss: 0.1197 - val_acc: 0.8372
# Epoch 52/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0417 - acc: 0.9491 - val_loss: 0.1253 - val_acc: 0.8295
# Epoch 53/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0411 - acc: 0.9542 - val_loss: 0.1276 - val_acc: 0.8295
# Epoch 54/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0418 - acc: 0.9477 - val_loss: 0.1339 - val_acc: 0.8062
# Epoch 55/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0413 - acc: 0.9520 - val_loss: 0.1268 - val_acc: 0.8140
# Epoch 56/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0419 - acc: 0.9506 - val_loss: 0.1186 - val_acc: 0.8295
# Epoch 57/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0442 - acc: 0.9398 - val_loss: 0.1233 - val_acc: 0.8295
# Epoch 58/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0384 - acc: 0.9542 - val_loss: 0.1169 - val_acc: 0.8372
# Epoch 59/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0426 - acc: 0.9448 - val_loss: 0.1374 - val_acc: 0.8140
# Epoch 60/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0420 - acc: 0.9477 - val_loss: 0.1251 - val_acc: 0.8217
# Epoch 61/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0414 - acc: 0.9484 - val_loss: 0.1188 - val_acc: 0.8372
# Epoch 62/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0449 - acc: 0.9427 - val_loss: 0.1210 - val_acc: 0.8372
# Epoch 63/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0376 - acc: 0.9549 - val_loss: 0.1178 - val_acc: 0.8372
# Epoch 64/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0447 - acc: 0.9434 - val_loss: 0.1213 - val_acc: 0.8295
# Epoch 65/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0426 - acc: 0.9448 - val_loss: 0.1272 - val_acc: 0.8217
# Epoch 66/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0394 - acc: 0.9499 - val_loss: 0.1282 - val_acc: 0.8217
# Epoch 67/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0389 - acc: 0.9513 - val_loss: 0.1273 - val_acc: 0.8217
# Epoch 68/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0448 - acc: 0.9477 - val_loss: 0.1116 - val_acc: 0.8372
# Epoch 69/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0391 - acc: 0.9520 - val_loss: 0.1237 - val_acc: 0.8295
# Epoch 70/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0405 - acc: 0.9499 - val_loss: 0.1164 - val_acc: 0.8450
# Epoch 71/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0375 - acc: 0.9513 - val_loss: 0.1127 - val_acc: 0.8450
# Epoch 72/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0399 - acc: 0.9499 - val_loss: 0.1255 - val_acc: 0.8295
# Epoch 73/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0363 - acc: 0.9585 - val_loss: 0.1252 - val_acc: 0.8295
# Epoch 74/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0396 - acc: 0.9534 - val_loss: 0.1302 - val_acc: 0.8062
# Epoch 75/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0376 - acc: 0.9527 - val_loss: 0.1233 - val_acc: 0.8295
# Epoch 76/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0407 - acc: 0.9470 - val_loss: 0.1194 - val_acc: 0.8372
# Epoch 77/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0383 - acc: 0.9520 - val_loss: 0.1273 - val_acc: 0.8217
# Epoch 78/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0387 - acc: 0.9577 - val_loss: 0.1186 - val_acc: 0.8372
# Epoch 79/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0365 - acc: 0.9563 - val_loss: 0.1171 - val_acc: 0.8372
# Epoch 80/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0393 - acc: 0.9513 - val_loss: 0.1194 - val_acc: 0.8372
# Epoch 81/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0333 - acc: 0.9642 - val_loss: 0.1180 - val_acc: 0.8372
# Epoch 82/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0368 - acc: 0.9570 - val_loss: 0.1182 - val_acc: 0.8372
# Epoch 83/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0406 - acc: 0.9477 - val_loss: 0.1288 - val_acc: 0.8140
# Epoch 84/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0412 - acc: 0.9499 - val_loss: 0.1102 - val_acc: 0.8527
# Epoch 85/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0420 - acc: 0.9470 - val_loss: 0.1124 - val_acc: 0.8450
# Epoch 86/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0357 - acc: 0.9570 - val_loss: 0.1165 - val_acc: 0.8450
# Epoch 87/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0416 - acc: 0.9470 - val_loss: 0.1129 - val_acc: 0.8450
# Epoch 88/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0397 - acc: 0.9513 - val_loss: 0.1201 - val_acc: 0.8372
# Epoch 89/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0406 - acc: 0.9499 - val_loss: 0.1119 - val_acc: 0.8372
# Epoch 90/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0337 - acc: 0.9613 - val_loss: 0.1248 - val_acc: 0.8140
# Epoch 91/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0398 - acc: 0.9484 - val_loss: 0.1201 - val_acc: 0.8372
# Epoch 92/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0391 - acc: 0.9520 - val_loss: 0.1180 - val_acc: 0.8450
# Epoch 93/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0371 - acc: 0.9577 - val_loss: 0.1185 - val_acc: 0.8450
# Epoch 94/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0366 - acc: 0.9563 - val_loss: 0.1114 - val_acc: 0.8450
# Epoch 95/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0422 - acc: 0.9484 - val_loss: 0.1136 - val_acc: 0.8450
# Epoch 96/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0416 - acc: 0.9484 - val_loss: 0.1201 - val_acc: 0.8217
# Epoch 97/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0351 - acc: 0.9556 - val_loss: 0.1130 - val_acc: 0.8450
# Epoch 98/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0413 - acc: 0.9499 - val_loss: 0.1087 - val_acc: 0.8450
# Epoch 99/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0428 - acc: 0.9477 - val_loss: 0.1215 - val_acc: 0.8295
# Epoch 100/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0378 - acc: 0.9563 - val_loss: 0.1134 - val_acc: 0.8295
# Epoch 101/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0374 - acc: 0.9570 - val_loss: 0.1220 - val_acc: 0.8295
# Epoch 102/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0403 - acc: 0.9499 - val_loss: 0.1132 - val_acc: 0.8295
# Epoch 103/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0429 - acc: 0.9427 - val_loss: 0.1237 - val_acc: 0.8295
# Epoch 104/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0397 - acc: 0.9527 - val_loss: 0.1142 - val_acc: 0.8450
# Epoch 105/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0400 - acc: 0.9527 - val_loss: 0.1100 - val_acc: 0.8372
# Epoch 106/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0389 - acc: 0.9534 - val_loss: 0.1089 - val_acc: 0.8527
# Epoch 107/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0343 - acc: 0.9606 - val_loss: 0.1136 - val_acc: 0.8295
# Epoch 108/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0385 - acc: 0.9577 - val_loss: 0.1216 - val_acc: 0.8295
# Epoch 109/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0390 - acc: 0.9499 - val_loss: 0.1195 - val_acc: 0.8295
# Epoch 110/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0441 - acc: 0.9434 - val_loss: 0.1189 - val_acc: 0.8295
# Epoch 111/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0361 - acc: 0.9570 - val_loss: 0.1265 - val_acc: 0.8295
# Epoch 112/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0356 - acc: 0.9563 - val_loss: 0.1102 - val_acc: 0.8527
# Epoch 113/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0358 - acc: 0.9592 - val_loss: 0.1105 - val_acc: 0.8372
# Epoch 114/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0356 - acc: 0.9542 - val_loss: 0.1129 - val_acc: 0.8527
# Epoch 115/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0351 - acc: 0.9592 - val_loss: 0.1110 - val_acc: 0.8527
# Epoch 116/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0343 - acc: 0.9635 - val_loss: 0.1130 - val_acc: 0.8527
# Epoch 117/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0378 - acc: 0.9484 - val_loss: 0.1159 - val_acc: 0.8372
# Epoch 118/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0355 - acc: 0.9606 - val_loss: 0.1135 - val_acc: 0.8450
# Epoch 119/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0352 - acc: 0.9642 - val_loss: 0.1091 - val_acc: 0.8527
# Epoch 120/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0381 - acc: 0.9527 - val_loss: 0.1150 - val_acc: 0.8372
# Epoch 121/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0352 - acc: 0.9527 - val_loss: 0.1228 - val_acc: 0.8295
# Epoch 122/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0395 - acc: 0.9513 - val_loss: 0.1169 - val_acc: 0.8372
# Epoch 123/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0359 - acc: 0.9527 - val_loss: 0.1135 - val_acc: 0.8372
# Epoch 124/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0392 - acc: 0.9520 - val_loss: 0.1259 - val_acc: 0.8217
# Epoch 125/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0367 - acc: 0.9556 - val_loss: 0.1141 - val_acc: 0.8295
# Epoch 126/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0358 - acc: 0.9549 - val_loss: 0.1144 - val_acc: 0.8295
# Epoch 127/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0339 - acc: 0.9577 - val_loss: 0.1156 - val_acc: 0.8372
# Epoch 128/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0386 - acc: 0.9527 - val_loss: 0.1214 - val_acc: 0.8217
# Epoch 129/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0335 - acc: 0.9592 - val_loss: 0.1237 - val_acc: 0.8217
# Epoch 130/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0364 - acc: 0.9542 - val_loss: 0.1189 - val_acc: 0.8295
# Epoch 131/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0355 - acc: 0.9556 - val_loss: 0.1136 - val_acc: 0.8372
# Epoch 132/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0352 - acc: 0.9585 - val_loss: 0.1220 - val_acc: 0.8372
# Epoch 133/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0347 - acc: 0.9549 - val_loss: 0.1069 - val_acc: 0.8682
# Epoch 134/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0374 - acc: 0.9556 - val_loss: 0.1026 - val_acc: 0.8682
# Epoch 135/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0372 - acc: 0.9513 - val_loss: 0.1186 - val_acc: 0.8372
# Epoch 136/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0339 - acc: 0.9592 - val_loss: 0.1316 - val_acc: 0.8140
# Epoch 137/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0369 - acc: 0.9542 - val_loss: 0.1199 - val_acc: 0.8372
# Epoch 138/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0330 - acc: 0.9606 - val_loss: 0.1160 - val_acc: 0.8372
# Epoch 139/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0347 - acc: 0.9613 - val_loss: 0.1046 - val_acc: 0.8527
# Epoch 140/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0359 - acc: 0.9520 - val_loss: 0.1105 - val_acc: 0.8450
# Epoch 141/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0288 - acc: 0.9692 - val_loss: 0.1070 - val_acc: 0.8527
# Epoch 142/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0314 - acc: 0.9628 - val_loss: 0.1214 - val_acc: 0.8295
# Epoch 143/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0362 - acc: 0.9549 - val_loss: 0.1148 - val_acc: 0.8372
# Epoch 144/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0371 - acc: 0.9513 - val_loss: 0.1180 - val_acc: 0.8372
# Epoch 145/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0374 - acc: 0.9542 - val_loss: 0.1108 - val_acc: 0.8450
# Epoch 146/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0363 - acc: 0.9542 - val_loss: 0.1137 - val_acc: 0.8450
# Epoch 147/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0356 - acc: 0.9577 - val_loss: 0.1053 - val_acc: 0.8527
# Epoch 148/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0325 - acc: 0.9628 - val_loss: 0.1182 - val_acc: 0.8217
# Epoch 149/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0328 - acc: 0.9620 - val_loss: 0.1188 - val_acc: 0.8217
# Epoch 150/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0328 - acc: 0.9606 - val_loss: 0.1092 - val_acc: 0.8527
# Epoch 151/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0374 - acc: 0.9506 - val_loss: 0.1088 - val_acc: 0.8605
# Epoch 152/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0353 - acc: 0.9577 - val_loss: 0.1084 - val_acc: 0.8450
# Epoch 153/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0331 - acc: 0.9563 - val_loss: 0.1224 - val_acc: 0.8217
# Epoch 154/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0353 - acc: 0.9570 - val_loss: 0.1199 - val_acc: 0.8217
# Epoch 155/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0353 - acc: 0.9549 - val_loss: 0.1145 - val_acc: 0.8372
# Epoch 156/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0363 - acc: 0.9513 - val_loss: 0.1164 - val_acc: 0.8217
# Epoch 157/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0300 - acc: 0.9606 - val_loss: 0.1128 - val_acc: 0.8372
# Epoch 158/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0351 - acc: 0.9613 - val_loss: 0.1374 - val_acc: 0.7907
# Epoch 159/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0319 - acc: 0.9620 - val_loss: 0.1151 - val_acc: 0.8372
# Epoch 160/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0339 - acc: 0.9592 - val_loss: 0.1189 - val_acc: 0.8372
# Epoch 161/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0323 - acc: 0.9642 - val_loss: 0.1347 - val_acc: 0.7984
# Epoch 162/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0340 - acc: 0.9592 - val_loss: 0.1227 - val_acc: 0.8217
# Epoch 163/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0342 - acc: 0.9563 - val_loss: 0.1257 - val_acc: 0.8140
# Epoch 164/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0328 - acc: 0.9606 - val_loss: 0.1285 - val_acc: 0.8062
# Epoch 165/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0370 - acc: 0.9534 - val_loss: 0.1206 - val_acc: 0.8295
# Epoch 166/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0331 - acc: 0.9599 - val_loss: 0.1150 - val_acc: 0.8372
# Epoch 167/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0317 - acc: 0.9649 - val_loss: 0.1196 - val_acc: 0.8295
# Epoch 168/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0331 - acc: 0.9613 - val_loss: 0.1167 - val_acc: 0.8295
# Epoch 169/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0298 - acc: 0.9663 - val_loss: 0.1136 - val_acc: 0.8372
# Epoch 170/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0317 - acc: 0.9620 - val_loss: 0.1167 - val_acc: 0.8450
# Epoch 171/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0311 - acc: 0.9628 - val_loss: 0.1243 - val_acc: 0.8217
# Epoch 172/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0326 - acc: 0.9613 - val_loss: 0.1191 - val_acc: 0.8295
# Epoch 173/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0335 - acc: 0.9620 - val_loss: 0.1131 - val_acc: 0.8527
# Epoch 174/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0361 - acc: 0.9563 - val_loss: 0.1311 - val_acc: 0.8062
# Epoch 175/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0321 - acc: 0.9606 - val_loss: 0.1166 - val_acc: 0.8450
# Epoch 176/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0342 - acc: 0.9606 - val_loss: 0.1323 - val_acc: 0.8140
# Epoch 177/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0361 - acc: 0.9592 - val_loss: 0.1213 - val_acc: 0.8217
# Epoch 178/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0319 - acc: 0.9606 - val_loss: 0.1226 - val_acc: 0.8217
# Epoch 179/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0321 - acc: 0.9635 - val_loss: 0.1239 - val_acc: 0.8140
# Epoch 180/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0313 - acc: 0.9628 - val_loss: 0.1183 - val_acc: 0.8372
# Epoch 181/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0325 - acc: 0.9599 - val_loss: 0.1135 - val_acc: 0.8450
# Epoch 182/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0301 - acc: 0.9606 - val_loss: 0.1195 - val_acc: 0.8217
# Epoch 183/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0345 - acc: 0.9592 - val_loss: 0.1193 - val_acc: 0.8295
# Epoch 184/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0363 - acc: 0.9549 - val_loss: 0.1271 - val_acc: 0.8140
# Epoch 185/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0314 - acc: 0.9642 - val_loss: 0.1145 - val_acc: 0.8605
# Epoch 186/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0352 - acc: 0.9556 - val_loss: 0.1261 - val_acc: 0.8140
# Epoch 187/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0351 - acc: 0.9563 - val_loss: 0.1259 - val_acc: 0.8217
# Epoch 188/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0317 - acc: 0.9656 - val_loss: 0.1284 - val_acc: 0.8140
# Epoch 189/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0314 - acc: 0.9642 - val_loss: 0.1297 - val_acc: 0.8140
# Epoch 190/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0291 - acc: 0.9692 - val_loss: 0.1373 - val_acc: 0.8062
# Epoch 191/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0374 - acc: 0.9484 - val_loss: 0.1302 - val_acc: 0.8062
# Epoch 192/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0362 - acc: 0.9563 - val_loss: 0.1321 - val_acc: 0.8062
# Epoch 193/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0333 - acc: 0.9606 - val_loss: 0.1296 - val_acc: 0.8140
# Epoch 194/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0320 - acc: 0.9628 - val_loss: 0.1268 - val_acc: 0.8217
# Epoch 195/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0329 - acc: 0.9592 - val_loss: 0.1398 - val_acc: 0.7829
# Epoch 196/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0326 - acc: 0.9599 - val_loss: 0.1252 - val_acc: 0.8295
# Epoch 197/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0341 - acc: 0.9577 - val_loss: 0.1145 - val_acc: 0.8450
# Epoch 198/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0327 - acc: 0.9592 - val_loss: 0.1046 - val_acc: 0.8605
# Epoch 199/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0375 - acc: 0.9534 - val_loss: 0.1168 - val_acc: 0.8295
# Epoch 200/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0322 - acc: 0.9635 - val_loss: 0.1138 - val_acc: 0.8450
# Epoch 201/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0343 - acc: 0.9585 - val_loss: 0.1273 - val_acc: 0.8140
# Epoch 202/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0314 - acc: 0.9620 - val_loss: 0.1287 - val_acc: 0.8217
# Epoch 203/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0300 - acc: 0.9613 - val_loss: 0.1391 - val_acc: 0.7907
# Epoch 204/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0317 - acc: 0.9656 - val_loss: 0.1227 - val_acc: 0.8372
# Epoch 205/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0316 - acc: 0.9620 - val_loss: 0.1207 - val_acc: 0.8295
# Epoch 206/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0334 - acc: 0.9599 - val_loss: 0.1104 - val_acc: 0.8527
# Epoch 207/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0296 - acc: 0.9670 - val_loss: 0.1047 - val_acc: 0.8682
# Epoch 208/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0308 - acc: 0.9663 - val_loss: 0.1135 - val_acc: 0.8450
# Epoch 209/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0332 - acc: 0.9649 - val_loss: 0.1298 - val_acc: 0.8140
# Epoch 210/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0346 - acc: 0.9577 - val_loss: 0.1147 - val_acc: 0.8372
# Epoch 211/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0291 - acc: 0.9685 - val_loss: 0.1177 - val_acc: 0.8295
# Epoch 212/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0303 - acc: 0.9613 - val_loss: 0.1008 - val_acc: 0.8760
# Epoch 213/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0310 - acc: 0.9635 - val_loss: 0.1085 - val_acc: 0.8605
# Epoch 214/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0346 - acc: 0.9577 - val_loss: 0.1083 - val_acc: 0.8450
# Epoch 215/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0270 - acc: 0.9663 - val_loss: 0.1226 - val_acc: 0.8217
# Epoch 216/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0323 - acc: 0.9606 - val_loss: 0.1223 - val_acc: 0.8295
# Epoch 217/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0324 - acc: 0.9613 - val_loss: 0.1090 - val_acc: 0.8372
# Epoch 218/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0321 - acc: 0.9585 - val_loss: 0.1198 - val_acc: 0.8295
# Epoch 219/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0297 - acc: 0.9678 - val_loss: 0.1124 - val_acc: 0.8450
# Epoch 220/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0321 - acc: 0.9613 - val_loss: 0.1147 - val_acc: 0.8450
# Epoch 221/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0293 - acc: 0.9656 - val_loss: 0.1335 - val_acc: 0.8062
# Epoch 222/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0340 - acc: 0.9592 - val_loss: 0.1159 - val_acc: 0.8450
# Epoch 223/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0284 - acc: 0.9656 - val_loss: 0.1243 - val_acc: 0.8295
# Epoch 224/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0301 - acc: 0.9670 - val_loss: 0.1254 - val_acc: 0.8295
# Epoch 225/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0314 - acc: 0.9620 - val_loss: 0.1180 - val_acc: 0.8295
# Epoch 226/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0305 - acc: 0.9628 - val_loss: 0.1069 - val_acc: 0.8682
# Epoch 227/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0324 - acc: 0.9577 - val_loss: 0.1062 - val_acc: 0.8682
# Epoch 228/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0294 - acc: 0.9692 - val_loss: 0.1094 - val_acc: 0.8527
# Epoch 229/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0302 - acc: 0.9656 - val_loss: 0.1150 - val_acc: 0.8295
# Epoch 230/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0325 - acc: 0.9599 - val_loss: 0.1131 - val_acc: 0.8450
# Epoch 231/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0281 - acc: 0.9642 - val_loss: 0.1148 - val_acc: 0.8450
# Epoch 232/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0305 - acc: 0.9649 - val_loss: 0.1135 - val_acc: 0.8450
# Epoch 233/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0329 - acc: 0.9613 - val_loss: 0.1190 - val_acc: 0.8372
# Epoch 234/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0301 - acc: 0.9635 - val_loss: 0.1202 - val_acc: 0.8372
# Epoch 235/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0314 - acc: 0.9585 - val_loss: 0.1246 - val_acc: 0.8217
# Epoch 236/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0306 - acc: 0.9620 - val_loss: 0.1198 - val_acc: 0.8450
# Epoch 237/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0284 - acc: 0.9649 - val_loss: 0.1249 - val_acc: 0.8295
# Epoch 238/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0328 - acc: 0.9606 - val_loss: 0.1138 - val_acc: 0.8450
# Epoch 239/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0271 - acc: 0.9670 - val_loss: 0.1174 - val_acc: 0.8372
# Epoch 240/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0267 - acc: 0.9670 - val_loss: 0.1287 - val_acc: 0.8295
# Epoch 241/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0283 - acc: 0.9670 - val_loss: 0.1175 - val_acc: 0.8372
# Epoch 242/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0296 - acc: 0.9685 - val_loss: 0.1152 - val_acc: 0.8372
# Epoch 243/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0272 - acc: 0.9706 - val_loss: 0.1264 - val_acc: 0.8217
# Epoch 244/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0276 - acc: 0.9678 - val_loss: 0.1245 - val_acc: 0.8295
# Epoch 245/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0295 - acc: 0.9649 - val_loss: 0.1205 - val_acc: 0.8372
# Epoch 246/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0293 - acc: 0.9642 - val_loss: 0.1059 - val_acc: 0.8605
# Epoch 247/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0301 - acc: 0.9649 - val_loss: 0.1095 - val_acc: 0.8527
# Epoch 248/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0274 - acc: 0.9685 - val_loss: 0.1182 - val_acc: 0.8295
# Epoch 249/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0288 - acc: 0.9699 - val_loss: 0.1066 - val_acc: 0.8682
# Epoch 250/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0306 - acc: 0.9656 - val_loss: 0.1197 - val_acc: 0.8372
# Epoch 251/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0294 - acc: 0.9635 - val_loss: 0.1147 - val_acc: 0.8450
# Epoch 252/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0269 - acc: 0.9699 - val_loss: 0.1245 - val_acc: 0.8140
# Epoch 253/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0304 - acc: 0.9670 - val_loss: 0.1148 - val_acc: 0.8372
# Epoch 254/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0325 - acc: 0.9628 - val_loss: 0.1287 - val_acc: 0.8217
# Epoch 255/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0297 - acc: 0.9642 - val_loss: 0.1120 - val_acc: 0.8450
# Epoch 256/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0296 - acc: 0.9692 - val_loss: 0.1216 - val_acc: 0.8295
# Epoch 257/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0335 - acc: 0.9592 - val_loss: 0.1235 - val_acc: 0.8295
# Epoch 258/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0322 - acc: 0.9613 - val_loss: 0.1198 - val_acc: 0.8372
# Epoch 259/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0281 - acc: 0.9656 - val_loss: 0.1280 - val_acc: 0.8217
# Epoch 260/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0254 - acc: 0.9735 - val_loss: 0.1203 - val_acc: 0.8450
# Epoch 261/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0308 - acc: 0.9599 - val_loss: 0.1194 - val_acc: 0.8450
# Epoch 262/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0266 - acc: 0.9735 - val_loss: 0.1216 - val_acc: 0.8372
# Epoch 263/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0314 - acc: 0.9620 - val_loss: 0.1193 - val_acc: 0.8295
# Epoch 264/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0298 - acc: 0.9606 - val_loss: 0.1167 - val_acc: 0.8295
# Epoch 265/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0286 - acc: 0.9635 - val_loss: 0.1193 - val_acc: 0.8295
# Epoch 266/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0302 - acc: 0.9628 - val_loss: 0.1244 - val_acc: 0.8295
# Epoch 267/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0321 - acc: 0.9642 - val_loss: 0.1209 - val_acc: 0.8295
# Epoch 268/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0229 - acc: 0.9749 - val_loss: 0.1210 - val_acc: 0.8372
# Epoch 269/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0309 - acc: 0.9620 - val_loss: 0.1149 - val_acc: 0.8450
# Epoch 270/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0275 - acc: 0.9678 - val_loss: 0.1324 - val_acc: 0.8062
# Epoch 271/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0301 - acc: 0.9635 - val_loss: 0.1181 - val_acc: 0.8372
# Epoch 272/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0275 - acc: 0.9692 - val_loss: 0.1082 - val_acc: 0.8527
# Epoch 273/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0281 - acc: 0.9656 - val_loss: 0.1201 - val_acc: 0.8295
# Epoch 274/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0283 - acc: 0.9670 - val_loss: 0.1079 - val_acc: 0.8450
# Epoch 275/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0276 - acc: 0.9692 - val_loss: 0.1255 - val_acc: 0.8295
# Epoch 276/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0261 - acc: 0.9685 - val_loss: 0.1324 - val_acc: 0.8140
# Epoch 277/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0258 - acc: 0.9706 - val_loss: 0.1317 - val_acc: 0.8140
# Epoch 278/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0269 - acc: 0.9663 - val_loss: 0.1215 - val_acc: 0.8372
# Epoch 279/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0323 - acc: 0.9599 - val_loss: 0.1315 - val_acc: 0.8140
# Epoch 280/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0270 - acc: 0.9678 - val_loss: 0.1192 - val_acc: 0.8295
# Epoch 281/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0257 - acc: 0.9713 - val_loss: 0.1024 - val_acc: 0.8605
# Epoch 282/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0274 - acc: 0.9692 - val_loss: 0.1217 - val_acc: 0.8295
# Epoch 283/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0273 - acc: 0.9713 - val_loss: 0.1244 - val_acc: 0.8295
# Epoch 284/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0277 - acc: 0.9642 - val_loss: 0.1160 - val_acc: 0.8372
# Epoch 285/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0305 - acc: 0.9613 - val_loss: 0.1232 - val_acc: 0.8295
# Epoch 286/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0274 - acc: 0.9685 - val_loss: 0.1043 - val_acc: 0.8605
# Epoch 287/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0288 - acc: 0.9635 - val_loss: 0.1270 - val_acc: 0.8217
# Epoch 288/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0260 - acc: 0.9699 - val_loss: 0.1364 - val_acc: 0.8062
# Epoch 289/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0274 - acc: 0.9649 - val_loss: 0.1227 - val_acc: 0.8295
# Epoch 290/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0271 - acc: 0.9670 - val_loss: 0.1319 - val_acc: 0.8217
# Epoch 291/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0261 - acc: 0.9692 - val_loss: 0.1213 - val_acc: 0.8295
# Epoch 292/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0248 - acc: 0.9706 - val_loss: 0.1130 - val_acc: 0.8295
# Epoch 293/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0299 - acc: 0.9670 - val_loss: 0.1074 - val_acc: 0.8527
# Epoch 294/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0271 - acc: 0.9685 - val_loss: 0.1098 - val_acc: 0.8450
# Epoch 295/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0272 - acc: 0.9670 - val_loss: 0.1225 - val_acc: 0.8295
# Epoch 296/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0297 - acc: 0.9628 - val_loss: 0.1124 - val_acc: 0.8295
# Epoch 297/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0274 - acc: 0.9649 - val_loss: 0.1261 - val_acc: 0.8217
# Epoch 298/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0282 - acc: 0.9685 - val_loss: 0.1261 - val_acc: 0.8217
# Epoch 299/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0263 - acc: 0.9678 - val_loss: 0.1123 - val_acc: 0.8450
# Epoch 300/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0299 - acc: 0.9642 - val_loss: 0.1270 - val_acc: 0.8295
# Epoch 301/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0263 - acc: 0.9670 - val_loss: 0.1250 - val_acc: 0.8295
# Epoch 302/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0246 - acc: 0.9721 - val_loss: 0.1191 - val_acc: 0.8295
# Epoch 303/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0282 - acc: 0.9678 - val_loss: 0.1191 - val_acc: 0.8295
# Epoch 304/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0294 - acc: 0.9663 - val_loss: 0.1201 - val_acc: 0.8217
# Epoch 305/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0288 - acc: 0.9713 - val_loss: 0.1208 - val_acc: 0.8295
# Epoch 306/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0303 - acc: 0.9628 - val_loss: 0.1201 - val_acc: 0.8295
# Epoch 307/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0234 - acc: 0.9721 - val_loss: 0.1171 - val_acc: 0.8372
# Epoch 308/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0277 - acc: 0.9685 - val_loss: 0.1331 - val_acc: 0.7984
# Epoch 309/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0314 - acc: 0.9620 - val_loss: 0.1178 - val_acc: 0.8372
# Epoch 310/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0249 - acc: 0.9728 - val_loss: 0.1174 - val_acc: 0.8295
# Epoch 311/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0293 - acc: 0.9692 - val_loss: 0.1198 - val_acc: 0.8217
# Epoch 312/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0255 - acc: 0.9749 - val_loss: 0.1063 - val_acc: 0.8527
# Epoch 313/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0264 - acc: 0.9678 - val_loss: 0.1112 - val_acc: 0.8450
# Epoch 314/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0259 - acc: 0.9670 - val_loss: 0.1083 - val_acc: 0.8450
# Epoch 315/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0282 - acc: 0.9670 - val_loss: 0.1179 - val_acc: 0.8295
# Epoch 316/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0251 - acc: 0.9735 - val_loss: 0.1086 - val_acc: 0.8527
# Epoch 317/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0282 - acc: 0.9663 - val_loss: 0.1143 - val_acc: 0.8372
# Epoch 318/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0264 - acc: 0.9735 - val_loss: 0.1188 - val_acc: 0.8372
# Epoch 319/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0229 - acc: 0.9771 - val_loss: 0.1206 - val_acc: 0.8295
# Epoch 320/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0280 - acc: 0.9685 - val_loss: 0.1180 - val_acc: 0.8372
# Epoch 321/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0253 - acc: 0.9699 - val_loss: 0.1120 - val_acc: 0.8372
# Epoch 322/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0298 - acc: 0.9613 - val_loss: 0.1201 - val_acc: 0.8295
# Epoch 323/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0264 - acc: 0.9699 - val_loss: 0.1128 - val_acc: 0.8450
# Epoch 324/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0255 - acc: 0.9706 - val_loss: 0.1052 - val_acc: 0.8527
# Epoch 325/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0234 - acc: 0.9728 - val_loss: 0.1210 - val_acc: 0.8372
# Epoch 326/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0277 - acc: 0.9670 - val_loss: 0.1057 - val_acc: 0.8605
# Epoch 327/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0256 - acc: 0.9692 - val_loss: 0.1193 - val_acc: 0.8295
# Epoch 328/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0279 - acc: 0.9635 - val_loss: 0.1114 - val_acc: 0.8450
# Epoch 329/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0249 - acc: 0.9749 - val_loss: 0.1152 - val_acc: 0.8372
# Epoch 330/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0275 - acc: 0.9678 - val_loss: 0.1200 - val_acc: 0.8372
# Epoch 331/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0240 - acc: 0.9756 - val_loss: 0.1096 - val_acc: 0.8527
# Epoch 332/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0278 - acc: 0.9663 - val_loss: 0.1066 - val_acc: 0.8527
# Epoch 333/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0306 - acc: 0.9613 - val_loss: 0.1077 - val_acc: 0.8450
# Epoch 334/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0282 - acc: 0.9642 - val_loss: 0.1215 - val_acc: 0.8372
# Epoch 335/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0268 - acc: 0.9670 - val_loss: 0.1078 - val_acc: 0.8450
# Epoch 336/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0283 - acc: 0.9656 - val_loss: 0.1201 - val_acc: 0.8372
# Epoch 337/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0299 - acc: 0.9656 - val_loss: 0.1041 - val_acc: 0.8605
# Epoch 338/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0253 - acc: 0.9649 - val_loss: 0.0992 - val_acc: 0.8682
# Epoch 339/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0267 - acc: 0.9678 - val_loss: 0.1121 - val_acc: 0.8372
# Epoch 340/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0242 - acc: 0.9742 - val_loss: 0.1200 - val_acc: 0.8295
# Epoch 341/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0238 - acc: 0.9713 - val_loss: 0.1245 - val_acc: 0.8217
# Epoch 342/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0247 - acc: 0.9728 - val_loss: 0.1042 - val_acc: 0.8682
# Epoch 343/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0248 - acc: 0.9706 - val_loss: 0.1081 - val_acc: 0.8605
# Epoch 344/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0255 - acc: 0.9656 - val_loss: 0.1079 - val_acc: 0.8527
# Epoch 345/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0231 - acc: 0.9749 - val_loss: 0.1062 - val_acc: 0.8527
# Epoch 346/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0233 - acc: 0.9721 - val_loss: 0.1185 - val_acc: 0.8372
# Epoch 347/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0245 - acc: 0.9735 - val_loss: 0.1121 - val_acc: 0.8295
# Epoch 348/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0253 - acc: 0.9678 - val_loss: 0.1218 - val_acc: 0.8295
# Epoch 349/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0232 - acc: 0.9728 - val_loss: 0.1177 - val_acc: 0.8295
# Epoch 350/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0252 - acc: 0.9706 - val_loss: 0.1204 - val_acc: 0.8295
# Epoch 351/500
# ...
# Epoch 385/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0231 - acc: 0.9692 - val_loss: 0.1009 - val_acc: 0.8682
# Epoch 386/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0217 - acc: 0.9706 - val_loss: 0.1157 - val_acc: 0.8372
# Epoch 387/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0269 - acc: 0.9685 - val_loss: 0.1025 - val_acc: 0.8450
# Epoch 388/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0250 - acc: 0.9706 - val_loss: 0.1033 - val_acc: 0.8450
# Epoch 389/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0290 - acc: 0.9620 - val_loss: 0.1088 - val_acc: 0.8527
# Epoch 390/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0296 - acc: 0.9635 - val_loss: 0.1003 - val_acc: 0.8527
# Epoch 391/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0271 - acc: 0.9635 - val_loss: 0.1077 - val_acc: 0.8372
# Epoch 392/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0208 - acc: 0.9778 - val_loss: 0.1153 - val_acc: 0.8372
# Epoch 393/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0225 - acc: 0.9749 - val_loss: 0.1051 - val_acc: 0.8450
# Epoch 394/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0253 - acc: 0.9685 - val_loss: 0.1058 - val_acc: 0.8527
# Epoch 395/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0246 - acc: 0.9678 - val_loss: 0.1112 - val_acc: 0.8372
# Epoch 396/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0224 - acc: 0.9742 - val_loss: 0.1215 - val_acc: 0.8295
# Epoch 397/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0268 - acc: 0.9742 - val_loss: 0.1268 - val_acc: 0.8217
# Epoch 398/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0281 - acc: 0.9678 - val_loss: 0.1298 - val_acc: 0.8217
# Epoch 399/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0229 - acc: 0.9735 - val_loss: 0.1203 - val_acc: 0.8295
# Epoch 400/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0240 - acc: 0.9699 - val_loss: 0.1264 - val_acc: 0.8295
# Epoch 401/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0230 - acc: 0.9756 - val_loss: 0.1228 - val_acc: 0.8295
# Epoch 402/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0220 - acc: 0.9771 - val_loss: 0.1191 - val_acc: 0.8295
# Epoch 403/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0234 - acc: 0.9742 - val_loss: 0.1196 - val_acc: 0.8295
# Epoch 404/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0255 - acc: 0.9706 - val_loss: 0.1105 - val_acc: 0.8450
# Epoch 405/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0258 - acc: 0.9713 - val_loss: 0.1064 - val_acc: 0.8760
# Epoch 406/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0244 - acc: 0.9735 - val_loss: 0.1278 - val_acc: 0.8217
# Epoch 407/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0249 - acc: 0.9663 - val_loss: 0.1228 - val_acc: 0.8217
# Epoch 408/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0244 - acc: 0.9706 - val_loss: 0.1117 - val_acc: 0.8527
# Epoch 409/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0245 - acc: 0.9713 - val_loss: 0.1161 - val_acc: 0.8295
# Epoch 410/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0217 - acc: 0.9721 - val_loss: 0.1223 - val_acc: 0.8217
# Epoch 411/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0269 - acc: 0.9692 - val_loss: 0.1222 - val_acc: 0.8140
# Epoch 412/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0220 - acc: 0.9735 - val_loss: 0.1179 - val_acc: 0.8295
# Epoch 413/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0252 - acc: 0.9692 - val_loss: 0.1100 - val_acc: 0.8527
# Epoch 414/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0223 - acc: 0.9735 - val_loss: 0.1051 - val_acc: 0.8682
# Epoch 415/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0228 - acc: 0.9706 - val_loss: 0.1172 - val_acc: 0.8295
# Epoch 416/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0236 - acc: 0.9706 - val_loss: 0.1233 - val_acc: 0.8140
# Epoch 417/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0238 - acc: 0.9713 - val_loss: 0.1183 - val_acc: 0.8217
# Epoch 418/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0264 - acc: 0.9670 - val_loss: 0.1097 - val_acc: 0.8527
# Epoch 419/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0222 - acc: 0.9756 - val_loss: 0.1242 - val_acc: 0.8062
# Epoch 420/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0230 - acc: 0.9742 - val_loss: 0.1269 - val_acc: 0.8062
# Epoch 421/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0238 - acc: 0.9692 - val_loss: 0.1193 - val_acc: 0.8295
# Epoch 422/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0229 - acc: 0.9713 - val_loss: 0.1225 - val_acc: 0.8217
# Epoch 423/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0249 - acc: 0.9699 - val_loss: 0.1222 - val_acc: 0.8217
# Epoch 424/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0223 - acc: 0.9728 - val_loss: 0.1212 - val_acc: 0.8217
# Epoch 425/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0241 - acc: 0.9678 - val_loss: 0.1135 - val_acc: 0.8372
# Epoch 426/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0212 - acc: 0.9742 - val_loss: 0.1055 - val_acc: 0.8605
# Epoch 427/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0229 - acc: 0.9699 - val_loss: 0.1040 - val_acc: 0.8605
# Epoch 428/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0239 - acc: 0.9728 - val_loss: 0.1135 - val_acc: 0.8605
# Epoch 429/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0228 - acc: 0.9749 - val_loss: 0.1017 - val_acc: 0.8605
# Epoch 430/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0207 - acc: 0.9749 - val_loss: 0.1131 - val_acc: 0.8605
# Epoch 431/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0204 - acc: 0.9771 - val_loss: 0.1208 - val_acc: 0.8295
# Epoch 432/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0235 - acc: 0.9699 - val_loss: 0.1216 - val_acc: 0.8295
# Epoch 433/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0232 - acc: 0.9742 - val_loss: 0.1164 - val_acc: 0.8372
# Epoch 434/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0234 - acc: 0.9742 - val_loss: 0.1238 - val_acc: 0.8140
# Epoch 435/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0257 - acc: 0.9663 - val_loss: 0.1061 - val_acc: 0.8605
# Epoch 436/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0223 - acc: 0.9742 - val_loss: 0.1187 - val_acc: 0.8295
# Epoch 437/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0231 - acc: 0.9735 - val_loss: 0.1213 - val_acc: 0.8295
# Epoch 438/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0242 - acc: 0.9721 - val_loss: 0.1102 - val_acc: 0.8605
# Epoch 439/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0240 - acc: 0.9706 - val_loss: 0.1289 - val_acc: 0.8217
# Epoch 440/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0226 - acc: 0.9771 - val_loss: 0.1231 - val_acc: 0.8295
# Epoch 441/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0219 - acc: 0.9742 - val_loss: 0.1214 - val_acc: 0.8295
# Epoch 442/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0227 - acc: 0.9756 - val_loss: 0.1245 - val_acc: 0.8295
# Epoch 443/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0212 - acc: 0.9764 - val_loss: 0.1216 - val_acc: 0.8295
# Epoch 444/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0221 - acc: 0.9749 - val_loss: 0.1346 - val_acc: 0.8062
# Epoch 445/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0224 - acc: 0.9749 - val_loss: 0.1375 - val_acc: 0.8062
# Epoch 446/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0229 - acc: 0.9735 - val_loss: 0.1180 - val_acc: 0.8217
# Epoch 447/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0216 - acc: 0.9756 - val_loss: 0.1292 - val_acc: 0.8140
# Epoch 448/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0238 - acc: 0.9721 - val_loss: 0.1445 - val_acc: 0.8062
# Epoch 449/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0223 - acc: 0.9735 - val_loss: 0.1245 - val_acc: 0.8217
# Epoch 450/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0216 - acc: 0.9785 - val_loss: 0.1273 - val_acc: 0.8140
# Epoch 451/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0201 - acc: 0.9764 - val_loss: 0.1338 - val_acc: 0.8062
# Epoch 452/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0223 - acc: 0.9735 - val_loss: 0.1048 - val_acc: 0.8605
# Epoch 453/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0250 - acc: 0.9670 - val_loss: 0.1183 - val_acc: 0.8295
# Epoch 454/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0211 - acc: 0.9742 - val_loss: 0.1218 - val_acc: 0.8140
# Epoch 455/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0204 - acc: 0.9764 - val_loss: 0.1189 - val_acc: 0.8295
# Epoch 456/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0200 - acc: 0.9778 - val_loss: 0.1242 - val_acc: 0.8295
# Epoch 457/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0224 - acc: 0.9749 - val_loss: 0.1284 - val_acc: 0.8217
# Epoch 458/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0234 - acc: 0.9735 - val_loss: 0.1366 - val_acc: 0.8062
# Epoch 459/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0216 - acc: 0.9706 - val_loss: 0.1341 - val_acc: 0.8062
# Epoch 460/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0173 - acc: 0.9799 - val_loss: 0.1238 - val_acc: 0.8217
# Epoch 461/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0246 - acc: 0.9706 - val_loss: 0.1190 - val_acc: 0.8295
# Epoch 462/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0217 - acc: 0.9749 - val_loss: 0.1341 - val_acc: 0.8140
# Epoch 463/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0234 - acc: 0.9728 - val_loss: 0.1305 - val_acc: 0.8062
# Epoch 464/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0235 - acc: 0.9771 - val_loss: 0.1213 - val_acc: 0.8295
# Epoch 465/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0231 - acc: 0.9735 - val_loss: 0.1425 - val_acc: 0.8062
# Epoch 466/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0220 - acc: 0.9728 - val_loss: 0.1348 - val_acc: 0.8140
# Epoch 467/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0240 - acc: 0.9713 - val_loss: 0.1322 - val_acc: 0.8295
# Epoch 468/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0209 - acc: 0.9749 - val_loss: 0.1169 - val_acc: 0.8372
# Epoch 469/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0232 - acc: 0.9706 - val_loss: 0.1243 - val_acc: 0.8295
# Epoch 470/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0192 - acc: 0.9764 - val_loss: 0.1128 - val_acc: 0.8527
# Epoch 471/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0214 - acc: 0.9764 - val_loss: 0.1160 - val_acc: 0.8372
# Epoch 472/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0196 - acc: 0.9778 - val_loss: 0.1128 - val_acc: 0.8450
# Epoch 473/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0230 - acc: 0.9756 - val_loss: 0.1143 - val_acc: 0.8372
# Epoch 474/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0224 - acc: 0.9756 - val_loss: 0.1338 - val_acc: 0.8140
# Epoch 475/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0210 - acc: 0.9749 - val_loss: 0.1337 - val_acc: 0.8140
# Epoch 476/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0217 - acc: 0.9771 - val_loss: 0.1169 - val_acc: 0.8372
# Epoch 477/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0230 - acc: 0.9749 - val_loss: 0.1217 - val_acc: 0.8217
# Epoch 478/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0213 - acc: 0.9749 - val_loss: 0.1300 - val_acc: 0.8140
# Epoch 479/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0210 - acc: 0.9728 - val_loss: 0.1113 - val_acc: 0.8527
# Epoch 480/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0227 - acc: 0.9721 - val_loss: 0.1206 - val_acc: 0.8372
# Epoch 481/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0216 - acc: 0.9756 - val_loss: 0.1137 - val_acc: 0.8527
# Epoch 482/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0251 - acc: 0.9692 - val_loss: 0.1283 - val_acc: 0.8295
# Epoch 483/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0210 - acc: 0.9771 - val_loss: 0.1157 - val_acc: 0.8450
# Epoch 484/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0250 - acc: 0.9699 - val_loss: 0.1115 - val_acc: 0.8450
# Epoch 485/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0207 - acc: 0.9749 - val_loss: 0.1114 - val_acc: 0.8527
# Epoch 486/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0213 - acc: 0.9778 - val_loss: 0.1213 - val_acc: 0.8372
# Epoch 487/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0215 - acc: 0.9785 - val_loss: 0.1263 - val_acc: 0.8217
# Epoch 488/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0215 - acc: 0.9749 - val_loss: 0.1201 - val_acc: 0.8372
# Epoch 489/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0184 - acc: 0.9807 - val_loss: 0.1231 - val_acc: 0.8295
# Epoch 490/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0229 - acc: 0.9742 - val_loss: 0.1279 - val_acc: 0.8140
# Epoch 491/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0207 - acc: 0.9756 - val_loss: 0.1269 - val_acc: 0.8217
# Epoch 492/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0217 - acc: 0.9699 - val_loss: 0.1191 - val_acc: 0.8372
# Epoch 493/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0173 - acc: 0.9835 - val_loss: 0.1100 - val_acc: 0.8527
# Epoch 494/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0232 - acc: 0.9685 - val_loss: 0.1005 - val_acc: 0.8682
# Epoch 495/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0219 - acc: 0.9735 - val_loss: 0.1064 - val_acc: 0.8372
# Epoch 496/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0207 - acc: 0.9756 - val_loss: 0.1097 - val_acc: 0.8450
# Epoch 497/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0197 - acc: 0.9792 - val_loss: 0.1084 - val_acc: 0.8682
# Epoch 498/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0229 - acc: 0.9713 - val_loss: 0.1146 - val_acc: 0.8295
# Epoch 499/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0218 - acc: 0.9721 - val_loss: 0.1051 - val_acc: 0.8682
# Epoch 500/500
# 1396/1396 [==============================] - 4s 3ms/step - loss: 0.0190 - acc: 0.9785 - val_loss: 0.1256 - val_acc: 0.8217
# dict_keys(['val_acc', 'val_loss', 'acc', 'loss'])

# %% [markdown]
# ##### Load pretrained conv model

# %%
# load json and create model
json_file = open('trained/conv_model_quickngood.json', 'r')
conv_model_json = json_file.read()
json_file.close()
model = model_from_json(conv_model_json)
# load weights into new model
model.load_weights("trained/conv_model_quickngood.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %% [markdown]
# ##### Additional model evaluation

# %%
# Evaluate model, get metrics back
stats = model.evaluate([x_dev, params_dev], y_dev)
# Calculate predictions vector from model
predictions = model.predict([x_dev, params_dev])
predictions = np.floor(predictions + 0.5)

# Get vector mask for good and bad fits and right and wrong answers
good_fits = y_dev
bad_fits = 1 - good_fits
wrong_answers = np.abs(np.subtract(predictions, good_fits))
right_answers = np.subtract(1, wrong_answers)
# Calculate true positives (tp), as well as (tn) (fp) (fn)
true_positives = np.multiply(right_answers, good_fits)
true_negatives = np.multiply(right_answers, bad_fits)
false_positives = np.multiply(wrong_answers, good_fits)
false_negatives = np.multiply(wrong_answers, bad_fits)
# Calculate additional metrics
precision = np.sum(true_positives) / np.sum(true_positives + false_positives)
recall = np.sum(true_positives) / np.sum(true_positives + false_negatives)

# Print stats
print()
print("Performance on VALIDATION set")
print(".............................")
print("Loss: " + str(stats[0]))
print("Accuracy: " + str(stats[1]))
print("Precision: " + str(precision))
print("Recall: " + str(recall))

# Print list of indices of wrong answers
bad_list = []
for i in range(m_dev):
    if wrong_answers[i] == 1:
        bad_list.append(i)
print(".............................")
print("List of indices of wrong guesses:")
print(bad_list)
# Out:
# 129/129 [==============================] - 0s 2ms/step
#
# Performance on VALIDATION set
# .............................
# Loss: 0.1132218891266524
# Accuracy: 0.8372093023255814
# Precision: 0.9107142857142857
# Recall: 0.7611940298507462
# .............................
# List of indices of wrong guesses:
# [3, 10, 14, 17, 18, 35, 42, 43, 46, 47, 49, 53, 74, 83, 85, 88, 97, 104, 105, 113, 121]

# %% [markdown]
# ##### Look at an image

# %%
# Choose an index 
index = 10

# Print labels for this index
print("label: " + str(good_fits[index]))
print("prediction: " + str(predictions[index]))

# Show image
this_image = x[index]
print(str(this_image.shape))
plt.imshow(np.uint8(utils.get_printable_image(this_image)))
# Out:
# label: [1]
# prediction: [0.]
# (236, 348, 3)

# %% [markdown]
# ##### Save convolutional model to disc

# %%
#plot_model(simple_model, to_file='simple_model.png')
#SVG(model_to_dot(simple_model).create(prog='dot', format='svg'))

# serialize model to JSON
model_json = model.to_json()
with open("trained/conv_model_all_1000.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("trained/conv_model_all_1000.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
