# %% [markdown]
# # Root fit analyzing neural network
#
#
# By Brady Lowe
#
# lowebra2@isu.edu
#
# 7/25/2018
#
#
# This Jupyter notebook was written to both develope and explain how we can use
# neural networks to analyze the output of root fits to raw data.

# %% [markdown]
# #### Load necessary packages

# %%
# Load some packages

# Keras packages for network
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, Conv2D, Flatten
from keras.models import Model
from keras.optimizers import Adam, SGD
# For saving model
from keras.models import model_from_json

# Some items for plotting and drawing
from keras.utils import plot_model
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG
from PIL import Image
from scipy import misc
import matplotlib.pyplot as plt

# Need numpy
import numpy as np
import nn_utils as utils

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Load root fit data from file

# %%
# Load dataset
x, y = utils.load_dataset_mysql(im_dir="train", log=True)
x_dev, y_dev = utils.load_dataset_mysql(im_dir="dev", log=True)

# Grab dimensions of picture
(m, h, w, c) = x.shape
m_dev = x_dev.shape[0]
input_shape = h, w, c

# Print dimensions
print("(m, height, width, channels): (" + str(m) + ", " + str(h) + ", " + str(w) + ", " + str(c) + ")")
print("m_dev: " + str(m_dev))
# Out:
# (m, height, width, channels): (2714, 236, 348, 3)
# m_dev: 350

# %%
# Print an image
index = 777
this_image = x[index]
if y[index] == 1:
    print("label: good")
else:
    print("label: bad")
print("label: " + str(y[index]))
plt.imshow(np.uint8(utils.get_printable_image(this_image)))
# Out:
# label: good
# label: [1]

# %% [markdown]
# ## Define and Train 3 layer ConvNet with 2 fully connected layers plus output layer
#
# For the convolutional layer, we will scan over our images with a certain stride and a certain kernal size.
# Each individual scan represents a single neuron in the next layer. Since each scan connects to kernal size squared
# neurons below it, convolutions reduce the number of degrees of freedom. Hopefully, through learning the right filters,
# we can preserve the important information as we reduce it in size.
#
# Once the image has gone through the convolutional layers (and therefore has been reduced to its features vector), we
# can send the resulting vector into some old-fashioned fully-connected layers, and finally into a logistic regression unit.

# %% [markdown]
# ##### Define hyperparameters

# %%
# Initialize
filters = []
kernels = []
strides = []
pools = []
dropouts = []

# Conv1
filters.append(16)
kernels.append(5)
strides.append(2)
pools.append(2)
dropouts.append(0.4)

# Conv2
filters.append(64)
kernels.append(5)
strides.append(2)
pools.append(2)
dropouts.append(0.4)

# Conv3
filters.append(256)
kernels.append(3)
strides.append(2)
pools.append(2)
dropouts.append(0.2)

# Conv4
filters.append(1024)
kernels.append(3)
strides.append(1)
pools.append(1)
dropouts.append(0.2)

# Define dense (fully-connected) layer sizes
fc1 = 30
fc2 = 30

# %% [markdown]
# ##### Define keras layers (model)

# %%
# Define input layer (RGB image matrix)
X = Input(shape=input_shape, name='Input')

# Initialize activation as input
a = X
# Loop through all convolutional layers
for i in range(len(filters)):
    # Perform convolution
    a = Conv2D(filters=filters[i], kernel_size=(kernels[i], kernels[i]), strides=(strides[i], strides[i]), name=('conv' + str(i)))(a)
    # Normalize
    a = BatchNormalization(axis=3, name=('bn' + str(i)))(a)
    # Activate
    a = Activation('relu', name=('a' + str(i)))(a)
    # Max-pool
    a = MaxPooling2D((pools[i], pools[i]), name=('max_pool' + str(i)))(a)
    # Dropout
    a = Dropout(rate=dropouts[i])(a)

# Flatten output of convNet
a = Flatten()(a)
# Define first fully connected layer
a = Dense(units=fc1, activation='relu', name='fc0')(a)
# Use some dropout here for regularization
a = Dropout(rate=0.2)(a)
# Define second fully connected layer
a = Dense(units=fc2, activation='relu', name='fc1')(a)
# Define output layer 
a = Dense(units=1, activation='sigmoid', name='sigmoid')(a)

# Make the model
model = Model(inputs=X, outputs=a)

# %% [markdown]
# ##### Define optimizer, loss, and metrics. Compile model.

# %%
# Define optimizer
#opt = Adam(lr=0.01, beta_1=0.9, beta_2=0.999, decay=0.001)
opt = SGD(lr=1.0, decay=1e-6, momentum=0.9, nesterov=True)
# Define loss
loss = 'mean_squared_error'
# Define metrics to use
metrics=['acc']
# Compile model
model.compile(loss=loss, optimizer='sgd', metrics=metrics)
# Print summary
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           (None, 236, 348, 3)       0
# _________________________________________________________________
# conv0 (Conv2D)               (None, 58, 86, 32)        4736
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 58, 86, 32)        128
# _________________________________________________________________
# a0 (Activation)              (None, 58, 86, 32)        0
# _________________________________________________________________
# max_pool0 (MaxPooling2D)     (None, 29, 43, 32)        0
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 29, 43, 32)        0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 9, 13, 128)        102528
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 9, 13, 128)        512
# _________________________________________________________________
# a1 (Activation)              (None, 9, 13, 128)        0
# _________________________________________________________________
# max_pool1 (MaxPooling2D)     (None, 4, 6, 128)         0
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 4, 6, 128)         0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 2, 4, 256)         295168
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 2, 4, 256)         1024
# _________________________________________________________________
# a2 (Activation)              (None, 2, 4, 256)         0
# _________________________________________________________________
# max_pool2 (MaxPooling2D)     (None, 2, 4, 256)         0
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 2, 4, 256)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# fc0 (Dense)                  (None, 20)                40980
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 20)                0
# _________________________________________________________________
# fc1 (Dense)                  (None, 10)                210
# _________________________________________________________________
# sigmoid (Dense)              (None, 1)                 11
# =================================================================
# Total params: 445,297
# Trainable params: 444,465
# Non-trainable params: 832
# _________________________________________________________________

# %% [markdown]
# ##### Fit the model to the data (train)

# %%
# Now, fit the model to the data
history = model.fit(x, y, validation_data=(x_dev, y_dev), epochs=2000, batch_size=32)

# List all data in history
print(history.history.keys())
# Summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Train on 2714 samples, validate on 350 samples
# Epoch 1/2000
# 2714/2714 [==============================] - 11s 4ms/step - loss: 0.0833 - acc: 0.9031 - val_loss: 0.0467 - val_acc: 0.9457
# Epoch 2/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0464 - acc: 0.9418 - val_loss: 0.0360 - val_acc: 0.9571
# Epoch 3/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0389 - acc: 0.9514 - val_loss: 0.0334 - val_acc: 0.9629
# Epoch 4/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0319 - acc: 0.9620 - val_loss: 0.0252 - val_acc: 0.9686
# Epoch 5/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0307 - acc: 0.9628 - val_loss: 0.0234 - val_acc: 0.9714
# Epoch 6/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0263 - acc: 0.9702 - val_loss: 0.0471 - val_acc: 0.9400
# Epoch 7/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0268 - acc: 0.9679 - val_loss: 0.0627 - val_acc: 0.9257
# Epoch 8/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0240 - acc: 0.9702 - val_loss: 0.0241 - val_acc: 0.9714
# Epoch 9/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0218 - acc: 0.9742 - val_loss: 0.0255 - val_acc: 0.9714
# Epoch 10/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0210 - acc: 0.9779 - val_loss: 0.0185 - val_acc: 0.9743
# Epoch 11/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0234 - acc: 0.9720 - val_loss: 0.0163 - val_acc: 0.9771
# Epoch 12/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0204 - acc: 0.9786 - val_loss: 0.0167 - val_acc: 0.9771
# Epoch 13/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0196 - acc: 0.9772 - val_loss: 0.0329 - val_acc: 0.9571
# Epoch 14/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0183 - acc: 0.9786 - val_loss: 0.0130 - val_acc: 0.9829
# Epoch 15/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0170 - acc: 0.9808 - val_loss: 0.0362 - val_acc: 0.9571
# Epoch 16/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0159 - acc: 0.9842 - val_loss: 0.0216 - val_acc: 0.9743
# Epoch 17/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0160 - acc: 0.9823 - val_loss: 0.0111 - val_acc: 0.9829
# Epoch 18/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0161 - acc: 0.9827 - val_loss: 0.0200 - val_acc: 0.9743
# Epoch 19/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0156 - acc: 0.9823 - val_loss: 0.0059 - val_acc: 0.9943
# Epoch 20/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0142 - acc: 0.9842 - val_loss: 0.0408 - val_acc: 0.9486
# Epoch 21/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0149 - acc: 0.9831 - val_loss: 0.0150 - val_acc: 0.9800
# Epoch 22/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0149 - acc: 0.9819 - val_loss: 0.0242 - val_acc: 0.9686
# Epoch 23/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0175 - acc: 0.9790 - val_loss: 0.0224 - val_acc: 0.9714
# Epoch 24/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0142 - acc: 0.9834 - val_loss: 0.0251 - val_acc: 0.9686
# Epoch 25/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0163 - acc: 0.9805 - val_loss: 0.0171 - val_acc: 0.9743
# Epoch 26/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0139 - acc: 0.9856 - val_loss: 0.0191 - val_acc: 0.9714
# Epoch 27/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0150 - acc: 0.9831 - val_loss: 0.0146 - val_acc: 0.9800
# Epoch 28/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0168 - acc: 0.9805 - val_loss: 0.0165 - val_acc: 0.9771
# Epoch 29/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0124 - acc: 0.9864 - val_loss: 0.0250 - val_acc: 0.9714
# Epoch 30/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0121 - acc: 0.9871 - val_loss: 0.0233 - val_acc: 0.9714
# Epoch 31/2000
# 2714/2714 [==============================] - 11s 4ms/step - loss: 0.0123 - acc: 0.9856 - val_loss: 0.0075 - val_acc: 0.9886
# Epoch 32/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0143 - acc: 0.9831 - val_loss: 0.0084 - val_acc: 0.9886
# Epoch 33/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0126 - acc: 0.9856 - val_loss: 0.0283 - val_acc: 0.9629
# Epoch 34/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0134 - acc: 0.9838 - val_loss: 0.0066 - val_acc: 0.9943
# Epoch 35/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0137 - acc: 0.9838 - val_loss: 0.0100 - val_acc: 0.9886
# Epoch 36/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0120 - acc: 0.9853 - val_loss: 0.0100 - val_acc: 0.9886
# Epoch 37/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0108 - acc: 0.9886 - val_loss: 0.0092 - val_acc: 0.9886
# Epoch 38/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0111 - acc: 0.9875 - val_loss: 0.0198 - val_acc: 0.9714
# Epoch 39/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0129 - acc: 0.9860 - val_loss: 0.0126 - val_acc: 0.9857
# Epoch 40/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0117 - acc: 0.9867 - val_loss: 0.0136 - val_acc: 0.9857
# Epoch 41/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0121 - acc: 0.9845 - val_loss: 0.0514 - val_acc: 0.9371
# Epoch 42/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0102 - acc: 0.9867 - val_loss: 0.0070 - val_acc: 0.9914
# Epoch 43/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0117 - acc: 0.9864 - val_loss: 0.0339 - val_acc: 0.9629
# Epoch 44/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0143 - acc: 0.9812 - val_loss: 0.0118 - val_acc: 0.9857
# Epoch 45/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0108 - acc: 0.9878 - val_loss: 0.0500 - val_acc: 0.9429
# Epoch 46/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0083 - acc: 0.9897 - val_loss: 0.0043 - val_acc: 0.9943
# Epoch 47/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0095 - acc: 0.9882 - val_loss: 0.0170 - val_acc: 0.9800
# Epoch 48/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0079 - acc: 0.9912 - val_loss: 0.0176 - val_acc: 0.9771
# Epoch 49/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0085 - acc: 0.9901 - val_loss: 0.0141 - val_acc: 0.9829
# Epoch 50/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0072 - acc: 0.9908 - val_loss: 0.0269 - val_acc: 0.9600
# Epoch 51/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0077 - acc: 0.9904 - val_loss: 0.0152 - val_acc: 0.9771
# Epoch 52/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0087 - acc: 0.9882 - val_loss: 0.0256 - val_acc: 0.9686
# Epoch 53/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0071 - acc: 0.9919 - val_loss: 0.0178 - val_acc: 0.9743
# Epoch 54/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0071 - acc: 0.9926 - val_loss: 0.0075 - val_acc: 0.9886
# Epoch 55/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0058 - acc: 0.9937 - val_loss: 0.0067 - val_acc: 0.9886
# Epoch 56/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0073 - acc: 0.9901 - val_loss: 0.0074 - val_acc: 0.9886
# Epoch 57/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0056 - acc: 0.9945 - val_loss: 0.0079 - val_acc: 0.9886
# Epoch 58/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0078 - acc: 0.9904 - val_loss: 0.0137 - val_acc: 0.9800
# Epoch 59/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0071 - acc: 0.9908 - val_loss: 0.0146 - val_acc: 0.9771
# Epoch 60/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0050 - acc: 0.9948 - val_loss: 0.0090 - val_acc: 0.9886
# Epoch 61/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0054 - acc: 0.9937 - val_loss: 0.0122 - val_acc: 0.9800
# Epoch 62/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0053 - acc: 0.9937 - val_loss: 0.0188 - val_acc: 0.9771
# Epoch 63/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0051 - acc: 0.9941 - val_loss: 0.0047 - val_acc: 0.9943
# Epoch 64/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0068 - acc: 0.9901 - val_loss: 0.0035 - val_acc: 0.9971
# Epoch 65/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0054 - acc: 0.9937 - val_loss: 0.0092 - val_acc: 0.9886
# Epoch 66/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0038 - acc: 0.9956 - val_loss: 0.0034 - val_acc: 0.9971
# Epoch 67/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0049 - acc: 0.9941 - val_loss: 0.0037 - val_acc: 0.9971
# Epoch 68/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0032 - acc: 0.9971 - val_loss: 0.0069 - val_acc: 0.9943
# Epoch 69/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0059 - acc: 0.9926 - val_loss: 0.0046 - val_acc: 0.9943
# Epoch 70/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0046 - acc: 0.9948 - val_loss: 0.0162 - val_acc: 0.9771
# Epoch 71/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0041 - acc: 0.9956 - val_loss: 0.0116 - val_acc: 0.9857
# Epoch 72/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0050 - acc: 0.9937 - val_loss: 0.0162 - val_acc: 0.9800
# Epoch 73/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0054 - acc: 0.9937 - val_loss: 0.0265 - val_acc: 0.9686
# Epoch 74/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0050 - acc: 0.9934 - val_loss: 0.0086 - val_acc: 0.9914
# Epoch 75/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0048 - acc: 0.9948 - val_loss: 0.0049 - val_acc: 0.9943
# Epoch 76/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0056 - acc: 0.9923 - val_loss: 0.0032 - val_acc: 0.9971
# Epoch 77/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0048 - acc: 0.9945 - val_loss: 0.0135 - val_acc: 0.9771
# Epoch 78/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0046 - acc: 0.9948 - val_loss: 0.0090 - val_acc: 0.9886
# Epoch 79/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0033 - acc: 0.9959 - val_loss: 0.0037 - val_acc: 0.9971
# Epoch 80/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0038 - acc: 0.9952 - val_loss: 0.0019 - val_acc: 0.9971
# Epoch 81/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0043 - acc: 0.9948 - val_loss: 0.0044 - val_acc: 0.9943
# Epoch 82/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0039 - acc: 0.9948 - val_loss: 0.0074 - val_acc: 0.9943
# Epoch 83/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0040 - acc: 0.9941 - val_loss: 0.0129 - val_acc: 0.9800
# Epoch 84/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0033 - acc: 0.9967 - val_loss: 0.0079 - val_acc: 0.9914
# Epoch 85/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0024 - acc: 0.9974 - val_loss: 0.0136 - val_acc: 0.9771
# Epoch 86/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0031 - acc: 0.9963 - val_loss: 0.0044 - val_acc: 0.9943
# Epoch 87/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0030 - acc: 0.9971 - val_loss: 0.0055 - val_acc: 0.9914
# Epoch 88/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0035 - acc: 0.9963 - val_loss: 0.0032 - val_acc: 0.9971
# Epoch 89/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0027 - acc: 0.9974 - val_loss: 0.0179 - val_acc: 0.9743
# Epoch 90/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0031 - acc: 0.9971 - val_loss: 0.0025 - val_acc: 0.9971
# Epoch 91/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0033 - acc: 0.9971 - val_loss: 0.0093 - val_acc: 0.9857
# Epoch 92/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0031 - acc: 0.9959 - val_loss: 0.0137 - val_acc: 0.9829
# Epoch 93/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0028 - acc: 0.9974 - val_loss: 0.0037 - val_acc: 0.9971
# Epoch 94/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0021 - acc: 0.9978 - val_loss: 0.0077 - val_acc: 0.9914
# Epoch 95/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0032 - acc: 0.9963 - val_loss: 0.0026 - val_acc: 0.9971
# Epoch 96/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0043 - acc: 0.9952 - val_loss: 0.0068 - val_acc: 0.9914
# Epoch 97/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0025 - acc: 0.9971 - val_loss: 0.0127 - val_acc: 0.9800
# Epoch 98/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0038 - acc: 0.9959 - val_loss: 0.0099 - val_acc: 0.9857
# Epoch 99/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0019 - acc: 0.9982 - val_loss: 0.0027 - val_acc: 0.9971
# Epoch 100/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0031 - acc: 0.9963 - val_loss: 0.0164 - val_acc: 0.9771
# Epoch 101/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0027 - acc: 0.9974 - val_loss: 0.0137 - val_acc: 0.9857
# Epoch 102/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0026 - acc: 0.9974 - val_loss: 0.0070 - val_acc: 0.9914
# Epoch 103/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0028 - acc: 0.9974 - val_loss: 0.0043 - val_acc: 0.9943
# Epoch 104/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0029 - acc: 0.9967 - val_loss: 0.0144 - val_acc: 0.9771
# Epoch 105/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0025 - acc: 0.9978 - val_loss: 0.0089 - val_acc: 0.9886
# Epoch 106/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0026 - acc: 0.9974 - val_loss: 0.0139 - val_acc: 0.9800
# Epoch 107/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0023 - acc: 0.9974 - val_loss: 0.0035 - val_acc: 0.9971
# Epoch 108/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0031 - acc: 0.9959 - val_loss: 0.0081 - val_acc: 0.9943
# Epoch 109/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0025 - acc: 0.9974 - val_loss: 0.0294 - val_acc: 0.9629
# Epoch 110/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0028 - acc: 0.9974 - val_loss: 0.0037 - val_acc: 0.9971
# Epoch 111/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0026 - acc: 0.9974 - val_loss: 0.0181 - val_acc: 0.9714
# Epoch 112/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9989 - val_loss: 0.0070 - val_acc: 0.9943
# Epoch 113/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0023 - acc: 0.9974 - val_loss: 0.0033 - val_acc: 0.9971
# Epoch 114/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0026 - acc: 0.9971 - val_loss: 0.0080 - val_acc: 0.9886
# Epoch 115/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0028 - acc: 0.9971 - val_loss: 0.0050 - val_acc: 0.9943
# Epoch 116/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0047 - acc: 0.9948 - val_loss: 0.0136 - val_acc: 0.9800
# Epoch 117/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0027 - acc: 0.9971 - val_loss: 0.0080 - val_acc: 0.9914
# Epoch 118/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0028 - acc: 0.9971 - val_loss: 0.0066 - val_acc: 0.9943
# Epoch 119/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0029 - acc: 0.9967 - val_loss: 0.0056 - val_acc: 0.9943
# Epoch 120/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0023 - acc: 0.9974 - val_loss: 0.0099 - val_acc: 0.9886
# Epoch 121/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0028 - acc: 0.9959 - val_loss: 0.0596 - val_acc: 0.9200
# Epoch 122/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0030 - acc: 0.9956 - val_loss: 0.0089 - val_acc: 0.9914
# Epoch 123/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0023 - acc: 0.9974 - val_loss: 0.0030 - val_acc: 0.9971
# Epoch 124/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0027 - acc: 0.9971 - val_loss: 0.0098 - val_acc: 0.9857
# Epoch 125/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0021 - acc: 0.9978 - val_loss: 0.0065 - val_acc: 0.9943
# Epoch 126/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0034 - acc: 0.9963 - val_loss: 0.0039 - val_acc: 0.9971
# Epoch 127/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0026 - acc: 0.9971 - val_loss: 0.0269 - val_acc: 0.9657
# Epoch 128/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0030 - acc: 0.9963 - val_loss: 0.0091 - val_acc: 0.9886
# Epoch 129/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0030 - acc: 0.9963 - val_loss: 0.0023 - val_acc: 0.9971
# Epoch 130/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0028 - acc: 0.9971 - val_loss: 0.0094 - val_acc: 0.9886
# Epoch 131/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0019 - acc: 0.9978 - val_loss: 0.0065 - val_acc: 0.9914
# Epoch 132/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0020 - acc: 0.9978 - val_loss: 0.0045 - val_acc: 0.9943
# Epoch 133/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0021 - acc: 0.9978 - val_loss: 0.0225 - val_acc: 0.9714
# Epoch 134/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0022 - acc: 0.9974 - val_loss: 0.0051 - val_acc: 0.9943
# Epoch 135/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0020 - acc: 0.9978 - val_loss: 0.0051 - val_acc: 0.9943
# Epoch 136/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0027 - acc: 0.9971 - val_loss: 0.0058 - val_acc: 0.9943
# Epoch 137/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0025 - acc: 0.9974 - val_loss: 0.0051 - val_acc: 0.9943
# Epoch 138/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0020 - acc: 0.9982 - val_loss: 0.0071 - val_acc: 0.9914
# Epoch 139/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0021 - acc: 0.9982 - val_loss: 0.0070 - val_acc: 0.9943
# Epoch 140/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0027 - acc: 0.9971 - val_loss: 0.0031 - val_acc: 0.9971
# Epoch 141/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0018 - acc: 0.9985 - val_loss: 0.0322 - val_acc: 0.9600
# Epoch 142/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0034 - acc: 0.9959 - val_loss: 0.0103 - val_acc: 0.9857
# Epoch 143/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0032 - acc: 0.9952 - val_loss: 0.0042 - val_acc: 0.9943
# Epoch 144/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0024 - acc: 0.9974 - val_loss: 0.0085 - val_acc: 0.9914
# Epoch 145/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0024 - acc: 0.9974 - val_loss: 0.0043 - val_acc: 0.9943
# Epoch 146/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0024 - acc: 0.9974 - val_loss: 0.0045 - val_acc: 0.9943
# Epoch 147/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0032 - acc: 0.9967 - val_loss: 0.0070 - val_acc: 0.9914
# Epoch 148/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0021 - acc: 0.9982 - val_loss: 0.0205 - val_acc: 0.9714
# Epoch 149/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0022 - acc: 0.9982 - val_loss: 0.0022 - val_acc: 0.9971
# Epoch 150/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0021 - acc: 0.9974 - val_loss: 0.0036 - val_acc: 0.9971
# Epoch 151/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0023 - acc: 0.9978 - val_loss: 0.0077 - val_acc: 0.9886
# Epoch 152/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0034 - acc: 0.9959 - val_loss: 0.0057 - val_acc: 0.9943
# Epoch 153/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0021 - acc: 0.9978 - val_loss: 0.0044 - val_acc: 0.9943
# Epoch 154/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0022 - acc: 0.9978 - val_loss: 0.0080 - val_acc: 0.9914
# Epoch 155/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0021 - acc: 0.9971 - val_loss: 0.0142 - val_acc: 0.9829
# Epoch 156/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0026 - acc: 0.9971 - val_loss: 0.0032 - val_acc: 0.9971
# Epoch 157/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0018 - acc: 0.9985 - val_loss: 0.0031 - val_acc: 0.9971
# Epoch 158/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0019 - acc: 0.9982 - val_loss: 0.0052 - val_acc: 0.9943
# Epoch 159/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0021 - acc: 0.9978 - val_loss: 0.0057 - val_acc: 0.9943
# Epoch 160/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0024 - acc: 0.9971 - val_loss: 0.0047 - val_acc: 0.9943
# Epoch 161/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0021 - acc: 0.9978 - val_loss: 0.0120 - val_acc: 0.9800
# Epoch 162/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0019 - acc: 0.9978 - val_loss: 0.0029 - val_acc: 0.9971
# Epoch 163/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0020 - acc: 0.9978 - val_loss: 0.0051 - val_acc: 0.9943
# Epoch 164/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0022 - acc: 0.9974 - val_loss: 0.0241 - val_acc: 0.9743
# Epoch 165/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0025 - acc: 0.9971 - val_loss: 0.0033 - val_acc: 0.9971
# Epoch 166/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0017 - acc: 0.9985 - val_loss: 0.0052 - val_acc: 0.9943
# Epoch 167/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0017 - acc: 0.9989 - val_loss: 0.0066 - val_acc: 0.9914
# Epoch 168/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0048 - val_acc: 0.9943
# Epoch 169/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0022 - acc: 0.9971 - val_loss: 0.0040 - val_acc: 0.9943
# Epoch 170/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0020 - acc: 0.9982 - val_loss: 0.0058 - val_acc: 0.9943
# Epoch 171/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0028 - acc: 0.9967 - val_loss: 0.0068 - val_acc: 0.9914
# Epoch 172/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0023 - acc: 0.9974 - val_loss: 0.0049 - val_acc: 0.9943
# Epoch 173/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0022 - acc: 0.9971 - val_loss: 0.0068 - val_acc: 0.9914
# Epoch 174/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0017 - acc: 0.9982 - val_loss: 0.0060 - val_acc: 0.9943
# Epoch 175/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0020 - acc: 0.9978 - val_loss: 0.0039 - val_acc: 0.9971
# Epoch 176/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0023 - acc: 0.9974 - val_loss: 0.0048 - val_acc: 0.9943
# Epoch 177/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0032 - acc: 0.9963 - val_loss: 0.0152 - val_acc: 0.9829
# Epoch 178/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0022 - acc: 0.9971 - val_loss: 0.0025 - val_acc: 0.9971
# Epoch 179/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0019 - acc: 0.9982 - val_loss: 0.0076 - val_acc: 0.9914
# Epoch 180/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0027 - acc: 0.9967 - val_loss: 0.0042 - val_acc: 0.9943
# Epoch 181/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0017 - acc: 0.9985 - val_loss: 0.0040 - val_acc: 0.9943
# Epoch 182/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0037 - val_acc: 0.9971
# Epoch 183/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0018 - acc: 0.9982 - val_loss: 0.0207 - val_acc: 0.9743
# Epoch 184/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9985 - val_loss: 0.0069 - val_acc: 0.9914
# Epoch 185/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0020 - acc: 0.9978 - val_loss: 0.0070 - val_acc: 0.9943
# Epoch 186/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0019 - acc: 0.9978 - val_loss: 0.0034 - val_acc: 0.9971
# Epoch 187/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0026 - acc: 0.9974 - val_loss: 0.0045 - val_acc: 0.9943
# Epoch 188/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0019 - acc: 0.9982 - val_loss: 0.0028 - val_acc: 0.9971
# Epoch 189/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9985 - val_loss: 0.0179 - val_acc: 0.9714
# Epoch 190/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0021 - acc: 0.9982 - val_loss: 0.0121 - val_acc: 0.9857
# Epoch 191/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9982 - val_loss: 0.0032 - val_acc: 0.9971
# Epoch 192/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0019 - acc: 0.9978 - val_loss: 0.0139 - val_acc: 0.9829
# Epoch 193/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9985 - val_loss: 0.0030 - val_acc: 0.9971
# Epoch 194/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0017 - acc: 0.9982 - val_loss: 0.0116 - val_acc: 0.9857
# Epoch 195/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0026 - acc: 0.9974 - val_loss: 0.0070 - val_acc: 0.9914
# Epoch 196/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0014 - acc: 0.9989 - val_loss: 0.0049 - val_acc: 0.9943
# Epoch 197/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0017 - acc: 0.9982 - val_loss: 0.0060 - val_acc: 0.9943
# Epoch 198/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0023 - acc: 0.9974 - val_loss: 0.0038 - val_acc: 0.9971
# Epoch 199/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9985 - val_loss: 0.0036 - val_acc: 0.9971
# Epoch 200/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9985 - val_loss: 0.0118 - val_acc: 0.9829
# Epoch 201/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0032 - acc: 0.9963 - val_loss: 0.0253 - val_acc: 0.9686
# Epoch 202/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0029 - acc: 0.9967 - val_loss: 0.0097 - val_acc: 0.9886
# Epoch 203/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0018 - acc: 0.9978 - val_loss: 0.0087 - val_acc: 0.9857
# Epoch 204/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0021 - acc: 0.9978 - val_loss: 0.0058 - val_acc: 0.9943
# Epoch 205/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0020 - acc: 0.9978 - val_loss: 0.0045 - val_acc: 0.9943
# Epoch 206/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9982 - val_loss: 0.0078 - val_acc: 0.9914
# Epoch 207/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0101 - val_acc: 0.9857
# Epoch 208/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0022 - acc: 0.9978 - val_loss: 0.0032 - val_acc: 0.9971
# Epoch 209/2000
# 2714/2714 [==============================] - 11s 4ms/step - loss: 0.0016 - acc: 0.9985 - val_loss: 0.0064 - val_acc: 0.9914
# Epoch 210/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0023 - acc: 0.9978 - val_loss: 0.0059 - val_acc: 0.9943
# Epoch 211/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9982 - val_loss: 0.0034 - val_acc: 0.9971
# Epoch 212/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0024 - acc: 0.9974 - val_loss: 0.0049 - val_acc: 0.9943
# Epoch 213/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9982 - val_loss: 0.0032 - val_acc: 0.9971
# Epoch 214/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0026 - acc: 0.9967 - val_loss: 0.0183 - val_acc: 0.9743
# Epoch 215/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9985 - val_loss: 0.0056 - val_acc: 0.9943
# Epoch 216/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0017 - acc: 0.9982 - val_loss: 0.0040 - val_acc: 0.9971
# Epoch 217/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9985 - val_loss: 0.0028 - val_acc: 0.9971
# Epoch 218/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0021 - acc: 0.9978 - val_loss: 0.0025 - val_acc: 0.9971
# Epoch 219/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0019 - acc: 0.9978 - val_loss: 0.0049 - val_acc: 0.9943
# Epoch 220/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0014 - acc: 0.9989 - val_loss: 0.0027 - val_acc: 0.9971
# Epoch 221/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0024 - acc: 0.9971 - val_loss: 0.0067 - val_acc: 0.9943
# Epoch 222/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0019 - acc: 0.9982 - val_loss: 0.0089 - val_acc: 0.9886
# Epoch 223/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0024 - acc: 0.9971 - val_loss: 0.0105 - val_acc: 0.9886
# Epoch 224/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0018 - acc: 0.9978 - val_loss: 0.0040 - val_acc: 0.9943
# Epoch 225/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0018 - acc: 0.9982 - val_loss: 0.0045 - val_acc: 0.9943
# Epoch 226/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0022 - acc: 0.9974 - val_loss: 0.0068 - val_acc: 0.9914
# Epoch 227/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0014 - acc: 0.9989 - val_loss: 0.0059 - val_acc: 0.9943
# Epoch 228/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9985 - val_loss: 0.0062 - val_acc: 0.9943
# Epoch 229/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0018 - acc: 0.9978 - val_loss: 0.0038 - val_acc: 0.9943
# Epoch 230/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0020 - acc: 0.9982 - val_loss: 0.0063 - val_acc: 0.9943
# Epoch 231/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0017 - acc: 0.9985 - val_loss: 0.0041 - val_acc: 0.9943
# Epoch 232/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0043 - val_acc: 0.9943
# Epoch 233/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0018 - acc: 0.9985 - val_loss: 0.0075 - val_acc: 0.9943
# Epoch 234/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0014 - acc: 0.9985 - val_loss: 0.0031 - val_acc: 0.9971
# Epoch 235/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0018 - acc: 0.9978 - val_loss: 0.0035 - val_acc: 0.9971
# Epoch 236/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0032 - val_acc: 0.9971
# Epoch 237/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0019 - acc: 0.9978 - val_loss: 0.0033 - val_acc: 0.9971
# Epoch 238/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0020 - acc: 0.9978 - val_loss: 0.0038 - val_acc: 0.9971
# Epoch 239/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0014 - acc: 0.9989 - val_loss: 0.0055 - val_acc: 0.9943
# Epoch 240/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0020 - acc: 0.9978 - val_loss: 0.0138 - val_acc: 0.9771
# Epoch 241/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0019 - acc: 0.9982 - val_loss: 0.0092 - val_acc: 0.9857
# Epoch 242/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0025 - acc: 0.9974 - val_loss: 0.0146 - val_acc: 0.9800
# Epoch 243/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0017 - acc: 0.9982 - val_loss: 0.0055 - val_acc: 0.9943
# Epoch 244/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0017 - acc: 0.9982 - val_loss: 0.0041 - val_acc: 0.9943
# Epoch 245/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9985 - val_loss: 0.0058 - val_acc: 0.9943
# Epoch 246/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0017 - acc: 0.9985 - val_loss: 0.0050 - val_acc: 0.9943
# Epoch 247/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0019 - acc: 0.9982 - val_loss: 0.0038 - val_acc: 0.9943
# Epoch 248/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0044 - val_acc: 0.9943
# Epoch 249/2000
# 2714/2714 [==============================] - 11s 4ms/step - loss: 0.0017 - acc: 0.9982 - val_loss: 0.0028 - val_acc: 0.9971
# Epoch 250/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0022 - acc: 0.9978 - val_loss: 0.0061 - val_acc: 0.9914
# Epoch 251/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0014 - acc: 0.9985 - val_loss: 0.0041 - val_acc: 0.9971
# Epoch 252/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0151 - val_acc: 0.9829
# Epoch 253/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0014 - acc: 0.9985 - val_loss: 0.0086 - val_acc: 0.9914
# Epoch 254/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0023 - acc: 0.9974 - val_loss: 0.0047 - val_acc: 0.9943
# Epoch 255/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0014 - acc: 0.9989 - val_loss: 0.0044 - val_acc: 0.9943
# Epoch 256/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0225 - val_acc: 0.9743
# Epoch 257/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0018 - acc: 0.9978 - val_loss: 0.0090 - val_acc: 0.9886
# Epoch 258/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9982 - val_loss: 0.0051 - val_acc: 0.9943
# Epoch 259/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0011 - acc: 0.9989 - val_loss: 0.0066 - val_acc: 0.9914
# Epoch 260/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0021 - acc: 0.9974 - val_loss: 0.0056 - val_acc: 0.9943
# Epoch 261/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9985 - val_loss: 0.0148 - val_acc: 0.9800
# Epoch 262/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0017 - acc: 0.9982 - val_loss: 0.0031 - val_acc: 0.9971
# Epoch 263/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0018 - acc: 0.9982 - val_loss: 0.0028 - val_acc: 0.9971
# Epoch 264/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0012 - acc: 0.9989 - val_loss: 0.0042 - val_acc: 0.9943
# Epoch 265/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0014 - acc: 0.9989 - val_loss: 0.0047 - val_acc: 0.9943
# Epoch 266/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9985 - val_loss: 0.0082 - val_acc: 0.9914
# Epoch 267/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0019 - acc: 0.9978 - val_loss: 0.0037 - val_acc: 0.9971
# Epoch 268/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0070 - val_acc: 0.9914
# Epoch 269/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9985 - val_loss: 0.0151 - val_acc: 0.9800
# Epoch 270/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9982 - val_loss: 0.0064 - val_acc: 0.9914
# Epoch 271/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9985 - val_loss: 0.0028 - val_acc: 0.9971
# Epoch 272/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0012 - acc: 0.9989 - val_loss: 0.0048 - val_acc: 0.9943
# Epoch 273/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0012 - acc: 0.9989 - val_loss: 0.0061 - val_acc: 0.9914
# Epoch 274/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0012 - acc: 0.9989 - val_loss: 0.0069 - val_acc: 0.9914
# Epoch 275/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0012 - acc: 0.9989 - val_loss: 0.0084 - val_acc: 0.9914
# Epoch 276/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9982 - val_loss: 0.0056 - val_acc: 0.9914
# Epoch 277/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9982 - val_loss: 0.0067 - val_acc: 0.9886
# Epoch 278/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0019 - acc: 0.9974 - val_loss: 0.0084 - val_acc: 0.9886
# Epoch 279/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9985 - val_loss: 0.0036 - val_acc: 0.9971
# Epoch 280/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9982 - val_loss: 0.0039 - val_acc: 0.9971
# Epoch 281/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9985 - val_loss: 0.0028 - val_acc: 0.9971
# Epoch 282/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0012 - acc: 0.9989 - val_loss: 0.0032 - val_acc: 0.9971
# Epoch 283/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9985 - val_loss: 0.0159 - val_acc: 0.9800
# Epoch 284/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0021 - acc: 0.9978 - val_loss: 0.0065 - val_acc: 0.9943
# Epoch 285/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9985 - val_loss: 0.0054 - val_acc: 0.9943
# Epoch 286/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0018 - acc: 0.9982 - val_loss: 0.0094 - val_acc: 0.9886
# Epoch 287/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0018 - acc: 0.9982 - val_loss: 0.0097 - val_acc: 0.9886
# Epoch 288/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0095 - val_acc: 0.9886
# Epoch 289/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0017 - acc: 0.9982 - val_loss: 0.0062 - val_acc: 0.9914
# Epoch 290/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0020 - acc: 0.9978 - val_loss: 0.0026 - val_acc: 0.9971
# Epoch 291/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9982 - val_loss: 0.0046 - val_acc: 0.9943
# Epoch 292/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9982 - val_loss: 0.0078 - val_acc: 0.9914
# Epoch 293/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0017 - acc: 0.9982 - val_loss: 0.0083 - val_acc: 0.9886
# Epoch 294/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0064 - val_acc: 0.9914
# Epoch 295/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0014 - acc: 0.9985 - val_loss: 0.0035 - val_acc: 0.9971
# Epoch 296/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9985 - val_loss: 0.0031 - val_acc: 0.9971
# Epoch 297/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9985 - val_loss: 0.0188 - val_acc: 0.9743
# Epoch 298/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9982 - val_loss: 0.0106 - val_acc: 0.9829
# Epoch 299/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0014 - acc: 0.9985 - val_loss: 0.0046 - val_acc: 0.9943
# Epoch 300/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9985 - val_loss: 0.0068 - val_acc: 0.9914
# Epoch 301/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9985 - val_loss: 0.0039 - val_acc: 0.9943
# Epoch 302/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0053 - val_acc: 0.9943
# Epoch 303/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0017 - acc: 0.9982 - val_loss: 0.0028 - val_acc: 0.9971
# Epoch 304/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0079 - val_acc: 0.9914
# Epoch 305/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0014 - acc: 0.9985 - val_loss: 0.0029 - val_acc: 0.9971
# Epoch 306/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9982 - val_loss: 0.0034 - val_acc: 0.9971
# Epoch 307/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9982 - val_loss: 0.0152 - val_acc: 0.9829
# Epoch 308/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9985 - val_loss: 0.0095 - val_acc: 0.9886
# Epoch 309/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0012 - acc: 0.9989 - val_loss: 0.0040 - val_acc: 0.9943
# Epoch 310/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0056 - val_acc: 0.9914
# Epoch 311/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0018 - acc: 0.9982 - val_loss: 0.0033 - val_acc: 0.9971
# Epoch 312/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9982 - val_loss: 0.0085 - val_acc: 0.9914
# Epoch 313/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0094 - val_acc: 0.9886
# Epoch 314/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9985 - val_loss: 0.0035 - val_acc: 0.9971
# Epoch 315/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0014 - acc: 0.9989 - val_loss: 0.0035 - val_acc: 0.9971
# Epoch 316/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0018 - acc: 0.9982 - val_loss: 0.0153 - val_acc: 0.9829
# Epoch 317/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0020 - acc: 0.9978 - val_loss: 0.0044 - val_acc: 0.9943
# Epoch 318/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0014 - acc: 0.9985 - val_loss: 0.0073 - val_acc: 0.9914
# Epoch 319/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0034 - val_acc: 0.9971
# Epoch 320/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9985 - val_loss: 0.0067 - val_acc: 0.9914
# Epoch 321/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9982 - val_loss: 0.0054 - val_acc: 0.9943
# Epoch 322/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0016 - acc: 0.9982 - val_loss: 0.0090 - val_acc: 0.9914
# Epoch 323/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0014 - acc: 0.9989 - val_loss: 0.0031 - val_acc: 0.9971
# Epoch 324/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0139 - val_acc: 0.9829
# Epoch 325/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9982 - val_loss: 0.0095 - val_acc: 0.9914
# Epoch 326/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9985 - val_loss: 0.0095 - val_acc: 0.9914
# Epoch 327/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0011 - acc: 0.9989 - val_loss: 0.0054 - val_acc: 0.9943
# Epoch 328/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0012 - acc: 0.9989 - val_loss: 0.0055 - val_acc: 0.9943
# Epoch 329/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0063 - val_acc: 0.9914
# Epoch 330/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0014 - acc: 0.9985 - val_loss: 0.0030 - val_acc: 0.9971
# Epoch 331/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0018 - acc: 0.9982 - val_loss: 0.0131 - val_acc: 0.9857
# Epoch 332/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0073 - val_acc: 0.9914
# Epoch 333/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0019 - acc: 0.9974 - val_loss: 0.0117 - val_acc: 0.9857
# Epoch 334/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0074 - val_acc: 0.9914
# Epoch 335/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0012 - acc: 0.9989 - val_loss: 0.0085 - val_acc: 0.9914
# Epoch 336/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0013 - acc: 0.9989 - val_loss: 0.0083 - val_acc: 0.9914
# Epoch 337/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0012 - acc: 0.9989 - val_loss: 0.0072 - val_acc: 0.9914
# Epoch 338/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0012 - acc: 0.9989 - val_loss: 0.0067 - val_acc: 0.9914
# Epoch 339/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0012 - acc: 0.9989 - val_loss: 0.0073 - val_acc: 0.9914
# Epoch 340/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0014 - acc: 0.9985 - val_loss: 0.0083 - val_acc: 0.9914
# Epoch 341/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0018 - acc: 0.9974 - val_loss: 0.0064 - val_acc: 0.9914
# Epoch 342/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9985 - val_loss: 0.0066 - val_acc: 0.9914
# Epoch 343/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0011 - acc: 0.9989 - val_loss: 0.0080 - val_acc: 0.9914
# Epoch 344/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0012 - acc: 0.9989 - val_loss: 0.0078 - val_acc: 0.9914
# Epoch 345/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 0.0015 - acc: 0.9989 - val_loss: 0.0057 - val_acc: 0.9914
# Epoch 346/2000
# ...
# Epoch 1891/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.7716e-04 - acc: 0.9996 - val_loss: 0.0107 - val_acc: 0.9857
# Epoch 1892/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.2294e-04 - acc: 0.9996 - val_loss: 0.0214 - val_acc: 0.9771
# Epoch 1893/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.3229e-04 - acc: 1.0000 - val_loss: 0.0268 - val_acc: 0.9686
# Epoch 1894/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.7986e-05 - acc: 1.0000 - val_loss: 0.0220 - val_acc: 0.9714
# Epoch 1895/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.8547e-04 - acc: 0.9996 - val_loss: 0.0043 - val_acc: 0.9971
# Epoch 1896/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.8583e-05 - acc: 1.0000 - val_loss: 0.0083 - val_acc: 0.9857
# Epoch 1897/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.4285e-05 - acc: 1.0000 - val_loss: 0.0108 - val_acc: 0.9857
# Epoch 1898/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.4124e-04 - acc: 0.9996 - val_loss: 0.0108 - val_acc: 0.9829
# Epoch 1899/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.0958e-04 - acc: 1.0000 - val_loss: 0.0150 - val_acc: 0.9800
# Epoch 1900/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.8743e-04 - acc: 0.9996 - val_loss: 0.0094 - val_acc: 0.9857
# Epoch 1901/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.2014e-04 - acc: 1.0000 - val_loss: 0.0101 - val_acc: 0.9857
# Epoch 1902/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.0249e-05 - acc: 1.0000 - val_loss: 0.0098 - val_acc: 0.9857
# Epoch 1903/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.2568e-04 - acc: 1.0000 - val_loss: 0.0141 - val_acc: 0.9800
# Epoch 1904/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 5.9301e-05 - acc: 1.0000 - val_loss: 0.0102 - val_acc: 0.9857
# Epoch 1905/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 4.3287e-05 - acc: 1.0000 - val_loss: 0.0142 - val_acc: 0.9800
# Epoch 1906/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.0655e-05 - acc: 1.0000 - val_loss: 0.0122 - val_acc: 0.9800
# Epoch 1907/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 7.2800e-05 - acc: 1.0000 - val_loss: 0.0128 - val_acc: 0.9800
# Epoch 1908/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.5795e-05 - acc: 1.0000 - val_loss: 0.0126 - val_acc: 0.9800
# Epoch 1909/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.5386e-04 - acc: 0.9993 - val_loss: 0.0152 - val_acc: 0.9800
# Epoch 1910/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.9088e-04 - acc: 0.9993 - val_loss: 0.0045 - val_acc: 0.9943
# Epoch 1911/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.0991e-04 - acc: 0.9996 - val_loss: 0.0108 - val_acc: 0.9857
# Epoch 1912/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 4.7201e-04 - acc: 0.9989 - val_loss: 0.0134 - val_acc: 0.9800
# Epoch 1913/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.9570e-05 - acc: 1.0000 - val_loss: 0.0120 - val_acc: 0.9829
# Epoch 1914/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.0104e-05 - acc: 1.0000 - val_loss: 0.0124 - val_acc: 0.9829
# Epoch 1915/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.7847e-05 - acc: 1.0000 - val_loss: 0.0120 - val_acc: 0.9829
# Epoch 1916/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.1012e-05 - acc: 1.0000 - val_loss: 0.0102 - val_acc: 0.9857
# Epoch 1917/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.7430e-04 - acc: 0.9996 - val_loss: 0.0084 - val_acc: 0.9857
# Epoch 1918/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.2309e-04 - acc: 1.0000 - val_loss: 0.0117 - val_acc: 0.9857
# Epoch 1919/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.9499e-05 - acc: 1.0000 - val_loss: 0.0121 - val_acc: 0.9857
# Epoch 1920/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.0628e-05 - acc: 1.0000 - val_loss: 0.0130 - val_acc: 0.9857
# Epoch 1921/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 7.3167e-04 - acc: 0.9989 - val_loss: 0.0093 - val_acc: 0.9886
# Epoch 1922/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.8217e-04 - acc: 0.9996 - val_loss: 0.0140 - val_acc: 0.9800
# Epoch 1923/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.0719e-04 - acc: 1.0000 - val_loss: 0.0141 - val_acc: 0.9800
# Epoch 1924/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.0116e-04 - acc: 1.0000 - val_loss: 0.0150 - val_acc: 0.9800
# Epoch 1925/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.9958e-05 - acc: 1.0000 - val_loss: 0.0139 - val_acc: 0.9800
# Epoch 1926/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.0004e-04 - acc: 0.9996 - val_loss: 0.0132 - val_acc: 0.9857
# Epoch 1927/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.9704e-04 - acc: 0.9993 - val_loss: 0.0112 - val_acc: 0.9886
# Epoch 1928/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.5340e-04 - acc: 0.9993 - val_loss: 0.0071 - val_acc: 0.9914
# Epoch 1929/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 5.5795e-05 - acc: 1.0000 - val_loss: 0.0102 - val_acc: 0.9886
# Epoch 1930/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 8.8422e-06 - acc: 1.0000 - val_loss: 0.0112 - val_acc: 0.9857
# Epoch 1931/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.5173e-04 - acc: 1.0000 - val_loss: 0.0114 - val_acc: 0.9857
# Epoch 1932/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.5963e-04 - acc: 1.0000 - val_loss: 0.0124 - val_acc: 0.9857
# Epoch 1933/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.3474e-05 - acc: 1.0000 - val_loss: 0.0125 - val_acc: 0.9857
# Epoch 1934/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.5267e-04 - acc: 0.9996 - val_loss: 0.0127 - val_acc: 0.9829
# Epoch 1935/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.1136e-05 - acc: 1.0000 - val_loss: 0.0120 - val_acc: 0.9857
# Epoch 1936/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.5608e-04 - acc: 0.9996 - val_loss: 0.0116 - val_acc: 0.9857
# Epoch 1937/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.1590e-04 - acc: 0.9996 - val_loss: 0.0127 - val_acc: 0.9857
# Epoch 1938/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.3326e-04 - acc: 0.9996 - val_loss: 0.0146 - val_acc: 0.9800
# Epoch 1939/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.5331e-04 - acc: 0.9996 - val_loss: 0.0195 - val_acc: 0.9743
# Epoch 1940/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 8.2158e-05 - acc: 1.0000 - val_loss: 0.0120 - val_acc: 0.9857
# Epoch 1941/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.4423e-05 - acc: 1.0000 - val_loss: 0.0129 - val_acc: 0.9829
# Epoch 1942/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.2169e-04 - acc: 0.9996 - val_loss: 0.0074 - val_acc: 0.9914
# Epoch 1943/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.6046e-04 - acc: 0.9996 - val_loss: 0.0151 - val_acc: 0.9829
# Epoch 1944/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.7437e-05 - acc: 1.0000 - val_loss: 0.0114 - val_acc: 0.9857
# Epoch 1945/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 4.6351e-06 - acc: 1.0000 - val_loss: 0.0116 - val_acc: 0.9857
# Epoch 1946/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.9421e-04 - acc: 0.9996 - val_loss: 0.0124 - val_acc: 0.9857
# Epoch 1947/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 9.3247e-05 - acc: 1.0000 - val_loss: 0.0130 - val_acc: 0.9829
# Epoch 1948/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 7.1233e-05 - acc: 1.0000 - val_loss: 0.0123 - val_acc: 0.9829
# Epoch 1949/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 4.7131e-05 - acc: 1.0000 - val_loss: 0.0106 - val_acc: 0.9857
# Epoch 1950/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 5.2422e-04 - acc: 0.9985 - val_loss: 0.0148 - val_acc: 0.9800
# Epoch 1951/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 4.1120e-05 - acc: 1.0000 - val_loss: 0.0125 - val_acc: 0.9829
# Epoch 1952/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.3725e-04 - acc: 0.9996 - val_loss: 0.0080 - val_acc: 0.9914
# Epoch 1953/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 4.2341e-05 - acc: 1.0000 - val_loss: 0.0137 - val_acc: 0.9800
# Epoch 1954/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.1595e-04 - acc: 1.0000 - val_loss: 0.0159 - val_acc: 0.9800
# Epoch 1955/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 8.8295e-05 - acc: 1.0000 - val_loss: 0.0145 - val_acc: 0.9800
# Epoch 1956/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.0353e-04 - acc: 0.9996 - val_loss: 0.0159 - val_acc: 0.9829
# Epoch 1957/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.2030e-05 - acc: 1.0000 - val_loss: 0.0155 - val_acc: 0.9829
# Epoch 1958/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.6107e-04 - acc: 1.0000 - val_loss: 0.0326 - val_acc: 0.9629
# Epoch 1959/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.7382e-05 - acc: 1.0000 - val_loss: 0.0220 - val_acc: 0.9714
# Epoch 1960/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 8.9115e-05 - acc: 1.0000 - val_loss: 0.0145 - val_acc: 0.9829
# Epoch 1961/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.3705e-05 - acc: 1.0000 - val_loss: 0.0136 - val_acc: 0.9829
# Epoch 1962/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.3107e-05 - acc: 1.0000 - val_loss: 0.0137 - val_acc: 0.9829
# Epoch 1963/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 4.3821e-04 - acc: 0.9996 - val_loss: 0.0034 - val_acc: 0.9971
# Epoch 1964/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.2139e-04 - acc: 1.0000 - val_loss: 0.0038 - val_acc: 0.9971
# Epoch 1965/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 5.3823e-05 - acc: 1.0000 - val_loss: 0.0064 - val_acc: 0.9886
# Epoch 1966/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.7831e-04 - acc: 0.9996 - val_loss: 0.0139 - val_acc: 0.9829
# Epoch 1967/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.4857e-04 - acc: 0.9996 - val_loss: 0.0163 - val_acc: 0.9800
# Epoch 1968/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.5042e-04 - acc: 1.0000 - val_loss: 0.0127 - val_acc: 0.9829
# Epoch 1969/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.0265e-04 - acc: 0.9996 - val_loss: 0.0130 - val_acc: 0.9829
# Epoch 1970/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 4.4568e-04 - acc: 0.9996 - val_loss: 0.0128 - val_acc: 0.9829
# Epoch 1971/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.2684e-04 - acc: 1.0000 - val_loss: 0.0074 - val_acc: 0.9914
# Epoch 1972/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.9214e-05 - acc: 1.0000 - val_loss: 0.0092 - val_acc: 0.9857
# Epoch 1973/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.9480e-05 - acc: 1.0000 - val_loss: 0.0091 - val_acc: 0.9886
# Epoch 1974/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 6.1238e-04 - acc: 0.9993 - val_loss: 0.0074 - val_acc: 0.9914
# Epoch 1975/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.4527e-04 - acc: 0.9996 - val_loss: 0.0079 - val_acc: 0.9886
# Epoch 1976/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.4843e-04 - acc: 0.9996 - val_loss: 0.0085 - val_acc: 0.9886
# Epoch 1977/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.1508e-04 - acc: 0.9996 - val_loss: 0.0402 - val_acc: 0.9514
# Epoch 1978/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 9.3561e-05 - acc: 1.0000 - val_loss: 0.0096 - val_acc: 0.9857
# Epoch 1979/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.6328e-05 - acc: 1.0000 - val_loss: 0.0109 - val_acc: 0.9857
# Epoch 1980/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.0849e-05 - acc: 1.0000 - val_loss: 0.0112 - val_acc: 0.9857
# Epoch 1981/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.3906e-04 - acc: 0.9993 - val_loss: 0.0197 - val_acc: 0.9771
# Epoch 1982/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 4.6434e-05 - acc: 1.0000 - val_loss: 0.0151 - val_acc: 0.9800
# Epoch 1983/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 8.9360e-05 - acc: 1.0000 - val_loss: 0.0033 - val_acc: 0.9971
# Epoch 1984/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.6383e-05 - acc: 1.0000 - val_loss: 0.0063 - val_acc: 0.9914
# Epoch 1985/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.4644e-05 - acc: 1.0000 - val_loss: 0.0083 - val_acc: 0.9886
# Epoch 1986/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.8958e-05 - acc: 1.0000 - val_loss: 0.0091 - val_acc: 0.9857
# Epoch 1987/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.2051e-04 - acc: 0.9996 - val_loss: 0.0131 - val_acc: 0.9800
# Epoch 1988/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.1000e-04 - acc: 0.9996 - val_loss: 0.0177 - val_acc: 0.9771
# Epoch 1989/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.0228e-05 - acc: 1.0000 - val_loss: 0.0145 - val_acc: 0.9800
# Epoch 1990/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.5847e-04 - acc: 0.9996 - val_loss: 0.0107 - val_acc: 0.9857
# Epoch 1991/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.4423e-04 - acc: 0.9996 - val_loss: 0.0269 - val_acc: 0.9686
# Epoch 1992/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 9.6473e-06 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9771
# Epoch 1993/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 3.8847e-04 - acc: 0.9996 - val_loss: 0.0083 - val_acc: 0.9886
# Epoch 1994/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 8.7617e-05 - acc: 1.0000 - val_loss: 0.0093 - val_acc: 0.9886
# Epoch 1995/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 5.3955e-05 - acc: 1.0000 - val_loss: 0.0092 - val_acc: 0.9886
# Epoch 1996/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 5.9403e-04 - acc: 0.9993 - val_loss: 0.0128 - val_acc: 0.9829
# Epoch 1997/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 1.9778e-05 - acc: 1.0000 - val_loss: 0.0142 - val_acc: 0.9800
# Epoch 1998/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.4335e-04 - acc: 0.9996 - val_loss: 0.0129 - val_acc: 0.9829
# Epoch 1999/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.4345e-04 - acc: 0.9996 - val_loss: 0.0112 - val_acc: 0.9886
# Epoch 2000/2000
# 2714/2714 [==============================] - 10s 4ms/step - loss: 2.9448e-04 - acc: 0.9996 - val_loss: 0.0123 - val_acc: 0.9829
# dict_keys(['loss', 'val_loss', 'val_acc', 'acc'])

# %% [markdown]
# ##### Load pretrained conv model

# %%
# load json and create model
json_file = open('trained/conv_model_quickngood.json', 'r')
conv_model_json = json_file.read()
json_file.close()
model = model_from_json(conv_model_json)
# load weights into new model
model.load_weights("trained/conv_model_quickngood.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %% [markdown]
# ##### Additional model evaluation

# %%
# This dataset was hand-labeled
x_test, y_test = utils.load_dataset(im_dir="dev_log")

# %%
x_val, y_val = x_dev, y_dev
# Evaluate model, get metrics back
stats = model.evaluate(x_val, y_val)
# Calculate predictions vector from model
predictions = model.predict(x_val)
predictions = np.floor(predictions + 0.5)

# Get vector mask for good and bad fits and right and wrong answers
good_fits = y_val
bad_fits = 1 - good_fits
wrong_answers = np.abs(np.subtract(predictions, good_fits))
right_answers = np.subtract(1, wrong_answers)
# Calculate true positives (tp), as well as (tn) (fp) (fn)
true_positives = np.multiply(right_answers, good_fits)
true_negatives = np.multiply(right_answers, bad_fits)
false_positives = np.multiply(wrong_answers, good_fits)
false_negatives = np.multiply(wrong_answers, bad_fits)
# Calculate additional metrics
precision = np.sum(true_positives) / np.sum(true_positives + false_positives)
recall = np.sum(true_positives) / np.sum(true_positives + false_negatives)

# Print stats
print()
print("Performance on VALIDATION set")
print(".............................")
print("Loss: " + str(stats[0]))
print("Accuracy: " + str(stats[1]))
print("Precision: " + str(precision))
print("Recall: " + str(recall))

# Print list of indices of wrong answers
bad_list = []
for i in range(m_dev):
    if wrong_answers[i] == 1:
        bad_list.append(i)
print(".............................")
print("List of indices of wrong guesses:")
print(bad_list)
# Out:
# 350/350 [==============================] - 1s 3ms/step
#
# Performance on VALIDATION set
# .............................
# Loss: 0.11709877678326198
# Accuracy: 0.862857141154153
# Precision: 0.8676470588235294
# Recall: 0.6020408163265306
# .............................
# List of indices of wrong guesses:
# [0, 1, 16, 51, 56, 58, 61, 65, 66, 68, 73, 75, 78, 79, 81, 85, 86, 87, 116, 151, 159, 162, 172, 177, 191, 192, 196, 198, 199, 200, 201, 207, 216, 225, 230, 249, 250, 258, 275, 279, 282, 304, 307, 329, 332, 341, 343, 344]

# %% [markdown]
# ##### Look at an image

# %%
# Choose an index 
index = 58

# Print labels for this index
print("label: " + str(good_fits[index]))
print("prediction: " + str(predictions[index]))

# Show image
this_image = x[index]
print(str(this_image.shape))
plt.imshow(np.uint8(utils.get_printable_image(this_image)))
# Out:
# label: [1]
# prediction: [0.]
# (236, 348, 3)

# %% [markdown]
# ##### Save convolutional model to disc

# %%
#plot_model(simple_model, to_file='simple_model.png')
#SVG(model_to_dot(simple_model).create(prog='dot', format='svg'))

# serialize model to JSON
model_json = model.to_json()
with open("trained/conv_model_quickngood_2000epoch_sql_log.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("trained/conv_model_quickngood_2000epoch_sql_log.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
